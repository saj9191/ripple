# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Small Lambda file")

params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": true,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Small Lambda file
# Current Git commit fd5e4f6 benchmark: Fix miscellaneous bugs
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530982878000.0
# 13:01:20: Waiting for combined function...
# 13:01:51: Waiting for combined function...
# 13:02:21: Found combined function
# 13:02:22: Waiting for percolator.decoy functions...
# 13:02:52: Found percolator.decoy functions
# 13:02:53: Found percolator.target functions
#
# Split Spectra
# Timestamp 1530982885958
# Billed Duration 4800 milliseconds
# Max Memory Used 470
# Cost 8.0016e-05
#
# Analyze Spectra
# Min Timestamp 1530982899236
# Max Timestamp 1530982914720
# Max Billed Duration 30300 milliseconds
# Total Billed Duration 144200 milliseconds
# Cost 0.002403814
#
# Combine Spectra
# Timestamp 1530982915006
# Billed Duration 4300 milliseconds
# Max Memory Used 95
# Cost 1.7930999999999998e-05
#
# Percolator Spectra
# Timestamp 1530982968923
# Billed Duration 49100 milliseconds
# Max Memory Used 532
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Big Lambda file")

params = json.loads("""{
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": true,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Big Lambda file
# Current Git commit f31ad33 benchmark: Add new line in print
# Iteration 0
# sorted_TN_CSF_062617_03.ms2 last modified 1530990984000.0
# 15:17:00: Waiting for combined function...
# 15:17:31: Waiting for combined function...
# 15:18:01: Waiting for combined function...
# 15:18:32: Waiting for combined function...
# 15:19:02: Found combined function
# 15:19:03: Waiting for percolator.decoy functions...
# 15:19:33: Waiting for percolator.decoy functions...
# 15:20:04: Found percolator.decoy functions
# 15:20:04: Found percolator.target functions
#
# Split Spectra
# Timestamp 1530991076718
# Billed Duration 56200 milliseconds
# Max Memory Used 920
# Cost 0.0009368540000000001
#
# Analyze Spectra
# Min Timestamp 1530991076734
# Max Timestamp 1530991113426
# Max Billed Duration 51300 milliseconds
# Total Billed Duration 455900 milliseconds
# Cost 0.007599853
#
# Combine Spectra
# Timestamp 1530991113811
# Billed Duration 8000 milliseconds
# Max Memory Used 140
# ...

# %%
print("hello")
# Out:
# hello
