# %%
import benchmark
import json

print("Run #1: Test with 1 Tide thread.")

params = json.loads("""
{
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 1000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #1: Test with 1 Tide thread.
# Current Git commit 246a773885a19f4437f436c8b581fcf699c18273
# Iteration 0
# 20170403_HelaQC_01.ms2 last modified 1530114117000.0
# 11:42:03: Waiting for combined function...
# 11:43:03: Found combined function
# 11:43:03: Waiting for decoy functions...
# 11:44:04: Waiting for decoy functions...
# 11:45:04: Found decoy functions
# 11:45:04: Found target functions
#
# Split Spectra
# Timestamp 1530114138252
# Billed Duration 15000 milliseconds
# Max Memory Used 487
# Cost 0.00025005000000000003
#
# Analyze Spectra
# Min Timestamp 1530114135968
# Max Timestamp 1530114156382
# Max Billed Duration 21400 milliseconds
# Total Billed Duration 730000 milliseconds
# Cost 0.0121691
#
# Combine Spectra
# Timestamp 1530114156673
# Billed Duration 6800 milliseconds
# Max Memory Used 84
# Cost 2.8355999999999998e-05
#
# Percolator Spectra
# Timestamp 1530114286692
# Billed Duration 123000 milliseconds
# Max Memory Used 714
# Cost 0.00205041
#
# END RESULTS
# ...

# %%
import benchmark
import json

print("Run #1: Test with 2 Tide threads.")

params = json.loads("""
{
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 1000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 2,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #1: Test with 2 Tide threads.
# Current Git commit 246a773885a19f4437f436c8b581fcf699c18273
# Iteration 0
# 20170403_HelaQC_01.ms2 last modified 1530117001000.0
# 12:30:10: Waiting for combined function...
# 12:31:11: Found combined function
# 12:31:11: Waiting for decoy functions...
# 12:32:12: Waiting for decoy functions...
# 12:33:12: Found decoy functions
# 12:33:13: Found target functions
#
# Split Spectra
# Timestamp 1530117021885
# Billed Duration 11000 milliseconds
# Max Memory Used 487
# Cost 0.00018337
#
# Analyze Spectra
# Min Timestamp 1530117025485
# Max Timestamp 1530117050698
# Max Billed Duration 29900 milliseconds
# Total Billed Duration 983800 milliseconds
# Cost 0.016399946000000002
#
# Combine Spectra
# Timestamp 1530117051042
# Billed Duration 6000 milliseconds
# Max Memory Used 85
# Cost 2.502e-05
#
# Percolator Spectra
# Timestamp 1530117177685
# Billed Duration 120600 milliseconds
# Max Memory Used 714
# Cost 0.002010402
#
# END RESULTS
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #3: Poll CPU to set the number of threads")

params = json.loads("""
{
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 1000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 0,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #3: Poll CPU to set the number of threads
# Current Git commit e8753b9b855883892375ce9d4428887a8e74cf0e
# Iteration 0
# 20170403_HelaQC_01.ms2 last modified 1530128701000.0
# 15:45:07: Waiting for combined function...
# 15:46:08: Found combined function
# 15:46:08: Waiting for decoy functions...
# 15:47:09: Waiting for decoy functions...
# 15:48:09: Found decoy functions
# 15:48:09: Found target functions
#
# Split Spectra
# Timestamp 1530128719761
# Billed Duration 12500 milliseconds
# Max Memory Used 488
# Cost 0.000208375
#
# Analyze Spectra
# Min Timestamp 1530128722795
# Max Timestamp 1530128750812
# Max Billed Duration 30400 milliseconds
# Total Billed Duration 1005100 milliseconds
# Cost 0.016755017
#
# Combine Spectra
# Timestamp 1530128751086
# Billed Duration 6500 milliseconds
# Max Memory Used 86
# Cost 2.7105e-05
#
# Percolator Spectra
# Timestamp 1530128879630
# Billed Duration 121800 milliseconds
# Max Memory Used 713
# Cost 0.0020304060000000002
#
# END RESULTS
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #4: Sort spectra by mass")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 1000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 0,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #4: Sort spectra by mass
# Current Git commit b0aacbf13b631e28450525632e579703c645471d
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530134390000.0
# 17:21:07: Waiting for combined function...
# 17:22:07: Found combined function
# 17:22:08: Waiting for decoy functions...
# 17:26:08: Found decoy functions
# 17:26:08: Found target functions
#
# Split Spectra
# Timestamp 1530134474280
# Billed Duration 18300 milliseconds
# Max Memory Used 487
# Cost 0.000305061
#
# Analyze Spectra
# Min Timestamp 1530134472429
# Max Timestamp 1530134489842
# Max Billed Duration 16000 milliseconds
# Total Billed Duration 573000 milliseconds
# Cost 0.00955191
#
# Combine Spectra
# Timestamp 1530134490383
# Billed Duration 7300 milliseconds
# Max Memory Used 84
# Cost 3.0441e-05
#
# Percolator Spectra
# Timestamp 1530134640180
# Billed Duration 141600 milliseconds
# Max Memory Used 712
# Cost 0.002360472
#
# END RESULTS
# Total Cost 0.012247884000000002
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #5: Sorted by mass with 1 Thread")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 1000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #5: Sorted by mass with 1 Thread
# Current Git commit b0aacbf13b631e28450525632e579703c645471d
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530137624000.0
# 18:15:49: Waiting for combined function...
# 18:16:50: Found combined function
# 18:16:50: Waiting for decoy functions...
# 18:17:50: Waiting for decoy functions...
# 18:18:51: Found decoy functions
# 18:18:51: Found target functions
#
# Split Spectra
# Timestamp 1530137763109
# Billed Duration 12900 milliseconds
# Max Memory Used 489
# Cost 0.00021504300000000002
#
# Analyze Spectra
# Min Timestamp 1530137762688
# Max Timestamp 1530137775687
# Max Billed Duration 15300 milliseconds
# Total Billed Duration 486300 milliseconds
# Cost 0.008106621
#
# Combine Spectra
# Timestamp 1530137776035
# Billed Duration 5700 milliseconds
# Max Memory Used 85
# Cost 2.3769e-05
#
# Percolator Spectra
# Timestamp 1530137907275
# Billed Duration 125500 milliseconds
# Max Memory Used 714
# Cost 0.002092085
#
# END RESULTS
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #6: Increase batch size to 2000")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 2000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #6: Increase batch size to 2000
# Current Git commit b0aacbf13b631e28450525632e579703c645471d
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530140956000.0
# 19:10:33: Waiting for combined function...
# 19:11:34: Found combined function
# 19:11:34: Waiting for decoy functions...
# 19:12:34: Waiting for decoy functions...
# 19:13:35: Waiting for decoy functions...
# 19:14:35: Found decoy functions
# 19:14:35: Found target functions
#
# Split Spectra
# Timestamp 1530141044025
# Billed Duration 10500 milliseconds
# Max Memory Used 496
# Cost 0.000175035
#
# Analyze Spectra
# Min Timestamp 1530141047800
# Max Timestamp 1530141063847
# Max Billed Duration 19700 milliseconds
# Total Billed Duration 318800 milliseconds
# Cost 0.005314396
#
# Combine Spectra
# Timestamp 1530141064254
# Billed Duration 7100 milliseconds
# Max Memory Used 94
# Cost 2.9607e-05
#
# Percolator Spectra
# Timestamp 1530141253101
# Billed Duration 184300 milliseconds
# Max Memory Used 713
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #7: Increase batch size to 4000")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 4000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #7: Increase batch size to 4000
# Current Git commit b0aacbf13b631e28450525632e579703c645471d
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530146214000.0
# 20:38:54: Waiting for combined function...
# 20:39:55: Found combined function
# 20:39:55: Waiting for decoy functions...
# 20:40:56: Waiting for decoy functions...
# 20:41:56: Found decoy functions
# 20:41:56: Found target functions
#
# Split Spectra
# Timestamp 1530146349087
# Billed Duration 14000 milliseconds
# Max Memory Used 525
# Cost 0.00023338000000000002
#
# Analyze Spectra
# Min Timestamp 1530146356445
# Max Timestamp 1530146375123
# Max Billed Duration 26100 milliseconds
# Total Billed Duration 224800 milliseconds
# Cost 0.0037474160000000004
#
# Combine Spectra
# Timestamp 1530146375627
# Billed Duration 7300 milliseconds
# Max Memory Used 106
# Cost 3.0441e-05
#
# Percolator Spectra
# Timestamp 1530146504842
# Billed Duration 121400 milliseconds
# Max Memory Used 724
# Cost 0.002023738
#
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #8: Increase batch size to 8000")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 8000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #8: Increase batch size to 8000
# Current Git commit b0aacbf13b631e28450525632e579703c645471d
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530149241000.0
# 21:29:26: Waiting for combined function...
# 21:30:26: Found combined function
# 21:30:26: Waiting for decoy functions...
# 21:31:27: Waiting for decoy functions...
# 21:32:28: Found decoy functions
# 21:32:28: Found target functions
#
# Split Spectra
# Timestamp 1530149376820
# Billed Duration 10800 milliseconds
# Max Memory Used 544
# Cost 0.000180036
#
# Analyze Spectra
# Min Timestamp 1530149390817
# Max Timestamp 1530149413552
# Max Billed Duration 36500 milliseconds
# Total Billed Duration 155300 milliseconds
# Cost 0.002588851
#
# Combine Spectra
# Timestamp 1530149413854
# Billed Duration 4700 milliseconds
# Max Memory Used 123
# Cost 1.9599e-05
#
# Percolator Spectra
# Timestamp 1530149542618
# Billed Duration 123100 milliseconds
# Max Memory Used 736
# Cost 0.0020520770000000002
#
# END RESULTS
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #9: Increase batch size to 16000")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 16000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #9: Increase batch size to 16000
# Current Git commit cfeaa7f494dfff82c78007d81adf92ab18a27c60
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530226403000.0
# 18:54:39: Waiting for combined function...
# 18:55:39: Found combined function
# 18:55:39: Waiting for decoy functions...
# 18:56:40: Waiting for decoy functions...
# 18:57:40: Waiting for decoy functions...
# 18:58:41: Found decoy functions
# 18:58:41: Found target functions
#
# Split Spectra
# Timestamp 1530226489341
# Billed Duration 10100 milliseconds
# Max Memory Used 600
# Cost 0.000168367
#
# Analyze Spectra
# Min Timestamp 1530226511833
# Max Timestamp 1530226520935
# Max Billed Duration 33100 milliseconds
# Total Billed Duration 90700 milliseconds
# Cost 0.0015119690000000002
#
# Combine Spectra
# Timestamp 1530226521413
# Billed Duration 4000 milliseconds
# Max Memory Used 149
# Cost 1.668e-05
#
# Percolator Spectra
# Timestamp 1530226713408
# Billed Duration 187700 milliseconds
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #10: Increase batch size to 32000")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 32000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #10: Increase batch size to 32000
# Current Git commit cfeaa7f494dfff82c78007d81adf92ab18a27c60
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530230932000.0
# 20:10:11: Waiting for combined function...
# 20:11:12: Waiting for combined function...
# 20:12:12: Found combined function
# 20:12:12: Waiting for decoy functions...
# 20:13:13: Waiting for decoy functions...
# 20:14:13: Found decoy functions
# 20:14:14: Found target functions
#
# Split Spectra
# Timestamp 1530231021570
# Billed Duration 9800 milliseconds
# Max Memory Used 636
# Cost 0.00016336600000000002
#
# Analyze Spectra
# Min Timestamp 1530231053266
# Max Timestamp 1530231071967
# Max Billed Duration 51800 milliseconds
# Total Billed Duration 83000 milliseconds
# Cost 0.0013836100000000002
#
# Combine Spectra
# Timestamp 1530231072253
# Billed Duration 6100 milliseconds
# Max Memory Used 132
# Cost 2.5437e-05
#
# Percolator Spectra
# Timestamp 1530231201371
# Billed Duration 122900 milliseconds
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #10: Increase batch size to 64000 (File only has 40Kish spectra)")

params = json.loads("""
{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "timeout": 300,
  "split_spectra": {
    "batch_size": 64000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Run #10: Increase batch size to 64000 (File only has 40Kish spectra)
# Current Git commit cfeaa7f494dfff82c78007d81adf92ab18a27c60
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1530234915000.0
# 21:17:05: Waiting for combined function...
# 21:18:06: Waiting for combined function...
# 21:19:06: Found combined function
# 21:19:06: Waiting for decoy functions...
# 21:20:07: Waiting for decoy functions...
# 21:21:07: Found decoy functions
# 21:21:07: Found target functions
#
# Split Spectra
# Timestamp 1530235035006
# Billed Duration 9500 milliseconds
# Max Memory Used 712
# Cost 0.00015836500000000002
#
# Analyze Spectra
# Min Timestamp 1530235111131
# Max Timestamp 1530235111131
# Max Billed Duration 75900 milliseconds
# Total Billed Duration 75900 milliseconds
# Cost 0.001265253
#
# Combine Spectra
# Timestamp 1530235112016
# Billed Duration 4700 milliseconds
# Max Memory Used 162
# Cost 1.9599e-05
#
# Percolator Spectra
# Timestamp 1530235242050
# ...
