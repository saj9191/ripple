# %%
import constants
import util
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(benchmark)

print("Test large file, no sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": False,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, no sort
# Current Git commit 1ceb2b9 benchmark: Fix spectra regex. More 10e+10
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531421967.494969-1-1-1.ms2 last modified 1531421970000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 1.5912578114318847
# Total Runtime 343.9953525066376 seconds
# Total Billed Duration 305.7605438232422 seconds
# Total Memory Used 0 MB
# key spectra-1531421967.494969-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531422328.339833-1-1-1.ms2 last modified 1531422331000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, pre sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "pre",
  "lambda": False,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, pre sort
# Current Git commit 1ceb2b9 benchmark: Fix spectra regex. More 10e+10
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Iteration 0
# Uploading sorted_TN_CSF_062617_03.ms2 to S3
# spectra-1531434450.983796-1-1-1.ms2 last modified 1531434454000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 1.4385507009379068
# Total Runtime 322.7868936061859 seconds
# Total Billed Duration 281.10794043540955 seconds
# Total Memory Used 0 MB
# key spectra-1531434450.983796-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "yes",
  "lambda": False,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, sort
# Current Git commit 1ceb2b9 benchmark: Fix spectra regex. More 10e+10
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531440029.779099-1-1-1.ms2 last modified 1531440032000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 2.135785422312418
# Total Runtime 434.14880895614624 seconds
# Total Billed Duration 394.9146695137024 seconds
# Total Memory Used 0 MB
# key spectra-1531440029.779099-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531440475.501784-1-1-1.ms2 last modified 1531440478000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, no sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, no sort
# Current Git commit e1b9060 lambda: Update logic to use regex for lambda
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531491572.766168-1-1-1.ms2 last modified 1531491575000.0
# 10:20:12: Waiting for spectra function...
# 10:20:43: Waiting for spectra function...
# 10:21:13: Waiting for spectra function...
# 10:21:44: Waiting for spectra function...
# 10:22:14: Found spectra function
# 10:22:15: Waiting for percolator.decoy functions...
# 10:22:45: Waiting for percolator.decoy functions...
# 10:23:15: Waiting for percolator.decoy functions...
# 10:23:46: Found percolator.decoy functions
# 10:23:47: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531491676258
# Billed Duration 63600 milliseconds
# Max Memory Used 453
# Cost 0.001060212
#
# analyze_spectra
# Min Timestamp 1531491627718
# Max Timestamp 1531491695347
# Max Billed Duration 29600 milliseconds
# Total Billed Duration 986100 milliseconds
# Cost 0.016438287
#
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, pre sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "pre",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, pre sort
# Current Git commit e1b9060 lambda: Update logic to use regex for lambda
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Iteration 0
# Uploading sorted_TN_CSF_062617_03.ms2 to S3
# spectra-1531494566.083146-1-1-1.ms2 last modified 1531494569000.0
# 11:10:26: Waiting for spectra function...
# 11:10:57: Waiting for spectra function...
# 11:11:27: Waiting for spectra function...
# 11:11:57: Found spectra function
# 11:11:58: Waiting for percolator.decoy functions...
# 11:12:28: Waiting for percolator.decoy functions...
# 11:12:59: Waiting for percolator.decoy functions...
# 11:13:29: Waiting for percolator.decoy functions...
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, sort 2K batches")

batch_size = 2000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "yes",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 1000000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, sort 2K batches
# Current Git commit 9bcf80b merge: Fix bugs
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531514520.542650-1-1-1.ms2 last modified 1531514523000.0
# 16:42:40: Waiting for spectra function...
# 16:43:10: Waiting for spectra function...
# 16:43:41: Waiting for spectra function...
# 16:44:11: Waiting for spectra function...
# 16:44:42: Waiting for spectra function...
# 16:45:12: Waiting for spectra function...
# 16:45:42: Found spectra function
# 16:45:43: Waiting for percolator.decoy functions...
# 16:46:14: Waiting for percolator.decoy functions...
# 16:46:44: Waiting for percolator.decoy functions...
# 16:47:14: Waiting for percolator.decoy functions...
# 16:47:45: Found percolator.decoy functions
# 16:47:45: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531514631907
# Billed Duration 71600 milliseconds
# Max Memory Used 579
# Cost 0.0011935720000000002
#
# sort_spectra
# Min Timestamp 1531514564307
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, sort 2K batches")

batch_size = 4000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "yes",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 1000000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, sort 2K batches
# Current Git commit 9bcf80b merge: Fix bugs
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531522410.689530-1-1-1.ms2 last modified 1531522413000.0
# 18:54:18: Waiting for spectra function...
# 18:54:48: Waiting for spectra function...
# 18:55:18: Waiting for spectra function...
# 18:55:49: Waiting for spectra function...
# 18:56:19: Waiting for spectra function...
# 18:56:49: Waiting for spectra function...
# 18:57:20: Waiting for spectra function...
# 18:57:50: Found spectra function
# 18:57:51: Waiting for percolator.decoy functions...
# 18:58:21: Waiting for percolator.decoy functions...
# 18:58:52: Waiting for percolator.decoy functions...
# 18:59:22: Found percolator.decoy functions
# 18:59:23: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531522534107
# Billed Duration 76200 milliseconds
# Max Memory Used 967
# Cost 0.0012702540000000002
#
# sort_spectra
# Min Timestamp 1531522466061
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, sort 2K batches")

batch_size = 5000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "yes",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 2048,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 1000000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, sort 2K batches
# Current Git commit 9bcf80b merge: Fix bugs
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531527774.284766-1-1-1.ms2 last modified 1531527777000.0
# 20:23:33: Waiting for spectra function...
# 20:24:04: Waiting for spectra function...
# 20:24:34: Waiting for spectra function...
# 20:25:04: Waiting for spectra function...
# 20:25:35: Waiting for spectra function...
# 20:26:05: Waiting for spectra function...
# 20:26:36: Found spectra function
# 20:26:36: Waiting for percolator.decoy functions...
# 20:27:06: Waiting for percolator.decoy functions...
# 20:27:37: Waiting for percolator.decoy functions...
# 20:28:07: Found percolator.decoy functions
# 20:28:08: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531527871807
# Billed Duration 58200 milliseconds
# Max Memory Used 1218
# Cost 0.0019403880000000001
#
# sort_spectra
# Min Timestamp 1531527819324
# Max Timestamp 1531527874040
# ...

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, pre sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "pre",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 0,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, pre sort
# Current Git commit f3c1e49 lambda: Allow splits in analysis function
#
#
# Iteration 0
# Uploading sorted_TN_CSF_062617_03.ms2 to S3
# spectra-1532026205.868560-1-0-1-1.ms2 last modified 1532026208000.0
# 14:50:43: Waiting for spectra function. Split 0 Analyze 0.
# 14:51:14: Waiting for spectra function. Split 0 Analyze 0.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-588427b69d2d> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     640 def lambda_benchmark(params):
# ...
