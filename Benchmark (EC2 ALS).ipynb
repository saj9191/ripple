# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #1: 215,914 spectra")
params = json.loads("""{
  "input_name": "sorted_ALS.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "user": "ec2-user"
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 100000,
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Run #1: 215,914 spectra
# Current Git commit 2bdb038 benchmark: Finish logic for EC2 instance
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.01417534540833367
# Total Runtime 1099.8112816810608 seconds
# Total Billed Duration 1099.8112816810608 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7c3c3f1b0a79> in <module>()
#      46 }
#      47 """)
# ---> 48 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#      58           results = lambda_benchmark(params)
#      59         else:
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #1: 215,914 spectra")
params = json.loads("""{
  "input_name": "sorted_ALS.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "cost": 0.0464,
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "user": "ec2-user"
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 100000,
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Run #1: 215,914 spectra
# Current Git commit 041d521 benchmark: Fix cost values
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.015370552372084722
# Total Runtime 1302.700739622116 seconds
# Total Billed Duration 1302.700739622116 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.014632303502400716
# Total Runtime 1261.380099773407 seconds
# Total Billed Duration 1261.380099773407 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.014457257709715099
# Total Runtime 1232.13898563385 seconds
# ...

# %%
# The above has a bug in the math. I accidentally added the setup stats twice,
# instead of the setup stats once and the analyze stats once.

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #1: Rerun. Bug in calculation")
params = json.loads("""{
  "input_name": "sorted_ALS.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "cost": 0.0464,
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "user": "ec2-user"
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 100000,
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Run #1: Rerun. Bug in calculation
# Current Git commit 2a9d4cc benchmark: Fix stats bu
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.009902807762569852
# Total Runtime 832.4033370018005 seconds
# Total Billed Duration 832.4033370018005 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.009119911852624682
# Total Runtime 771.6628222465515 seconds
# Total Billed Duration 771.6628222465515 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.009432027109675934
# Total Runtime 795.6820278167725 seconds
# ...

# %%
# Note. In the code above, all of the costs assumed milliseconds.
# This is fixed in the next run, but above all costs must be multipled by 60.

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #3: Use AMI image")
params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 100000,
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Run #3: Use AMI image
# Current Git commit 032e312 benchmark: Add ec2 costs
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.2217802184549967
# Total Runtime 396.9403190612793 seconds
# Total Billed Duration 396.9403190612793 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.24930816198348996
# Total Runtime 432.65637612342834 seconds
# Total Billed Duration 432.65637612342834 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22235308232625325
# Total Runtime 428.49859619140625 seconds
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Run #3: Do not use AMI image")
params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": false
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 100000,
    "memory_size": 1024,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Run #3: Do not use AMI image
# Current Git commit 032e312 benchmark: Add ec2 costs
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.2657634524091085
# Total Runtime 407.5275366306305 seconds
# Total Billed Duration 407.5275366306305 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.268999382387797
# Total Runtime 411.8403420448303 seconds
# Total Billed Duration 411.8403420448303 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.2162452840423584
# Total Runtime 358.893967628479 seconds
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Test ALS EC2 with AMI")

params = json.loads("""{
  "input_name": "ALS.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Test ALS EC2 with AMI
# Current Git commit 283b29b benchmark: Fix crux permission bug
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 7.054533608754476
# Total Runtime 1188.8923797607422 seconds
# Total Billed Duration 1188.8923797607422 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 7.320534978892008
# Total Runtime 1231.9612727165222 seconds
# Total Billed Duration 1231.9612727165222 seconds
# Total Memory Used 0 MB
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 7.585304872690837
# Total Runtime 1275.4381213188171 seconds
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Big file EC2")

params = json.loads("""{
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.xlarge",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Big file EC2
# Current Git commit f31ad33 benchmark: Add new line in print
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# b''
# ...

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Big file EC2")

params = json.loads("""{
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.xlarge",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")

benchmark.run(params)
# Out:
# Big file EC2
# Current Git commit f31ad33 benchmark: Add new line in print
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# b''
# ...
