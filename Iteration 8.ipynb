# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, pre sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, pre sort
# Current Git commit 7036a9e Benchmark: Upload spectra.py
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531762892.951435-1-1-1.ms2 last modified 1531762895000.0
# 13:42:12: Waiting for spectra function...
# 13:42:42: Waiting for spectra function...
# 13:43:13: Waiting for spectra function...
# 13:43:43: Waiting for spectra function...
# 13:44:14: Found spectra function
# 13:44:14: Waiting for percolator.decoy functions...
# 13:44:45: Waiting for percolator.decoy functions...
# 13:45:15: Waiting for percolator.decoy functions...
# 13:45:46: Found percolator.decoy functions
# 13:45:46: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531763014057
# Billed Duration 81800 milliseconds
# Max Memory Used 466
# Cost 0.001363606
#
# analyze_spectra
# Min Timestamp 1531762951635
# Max Timestamp 1531763033685
# Max Billed Duration 29400 milliseconds
# Total Billed Duration 1090300 milliseconds
# Cost 0.018175301
#
# Combine Spectra
# Timestamp 1531763033991
# Billed Duration 8600 milliseconds
# Max Memory Used 104
# Cost 3.5861999999999996e-05
#
# Percolator Spectra
# Timestamp 1531763144225
# Billed Duration 101300 milliseconds
# Max Memory Used 928
# Cost 0.004960661
#
# END RESULTS
# Total Cost 0.024535430000000004
# Total Runtime 259.9454718589783 seconds
# Total Billed Duration 1282.0 seconds
# Total Memory Used 41928 MB
# key spectra-1531762892.951435-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531763185.337728-1-1-1.ms2 last modified 1531763188000.0
# 13:47:04: Waiting for spectra function...
# 13:47:34: Waiting for spectra function...
# 13:48:05: Waiting for spectra function...
# 13:48:35: Waiting for spectra function...
# 13:49:05: Found spectra function
# 13:49:06: Waiting for percolator.decoy functions...
# 13:49:37: Waiting for percolator.decoy functions...
# 13:50:07: Waiting for percolator.decoy functions...
# 13:50:38: Found percolator.decoy functions
# 13:50:38: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531763303110
# Billed Duration 79400 milliseconds
# Max Memory Used 466
# Cost 0.001323598
#
# analyze_spectra
# Min Timestamp 1531763242342
# Max Timestamp 1531763321384
# Max Billed Duration 29300 milliseconds
# Total Billed Duration 1038400 milliseconds
# Cost 0.017310128
#
# Combine Spectra
# Timestamp 1531763321720
# Billed Duration 9700 milliseconds
# Max Memory Used 105
# Cost 4.0449e-05
#
# Percolator Spectra
# Timestamp 1531763432726
# Billed Duration 101600 milliseconds
# Max Memory Used 935
# Cost 0.004975352
#
# END RESULTS
# Total Cost 0.023649527
# Total Runtime 258.36089849472046 seconds
# Total Billed Duration 1229.1 seconds
# Total Memory Used 43879 MB
# key spectra-1531763185.337728-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531763475.753800-1-1-1.ms2 last modified 1531763478000.0
# 13:51:55: Waiting for spectra function...
# 13:52:25: Waiting for spectra function...
# 13:52:55: Waiting for spectra function...
# 13:53:26: Waiting for spectra function...
# 13:53:56: Found spectra function
# 13:53:57: Waiting for percolator.decoy functions...
# 13:54:27: Waiting for percolator.decoy functions...
# 13:54:58: Waiting for percolator.decoy functions...
# 13:55:28: Found percolator.decoy functions
# 13:55:28: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531763585329
# Billed Duration 70800 milliseconds
# Max Memory Used 466
# Cost 0.001180236
#
# analyze_spectra
# Min Timestamp 1531763529067
# Max Timestamp 1531763604081
# Max Billed Duration 26500 milliseconds
# Total Billed Duration 958200 milliseconds
# Cost 0.015973194
#
# Combine Spectra
# Timestamp 1531763604440
# Billed Duration 9700 milliseconds
# Max Memory Used 106
# Cost 4.0449e-05
#
# Percolator Spectra
# Timestamp 1531763714739
# Billed Duration 100900 milliseconds
# Max Memory Used 936
# Cost 0.004941073
#
# END RESULTS
# Total Cost 0.022134952000000003
# Total Runtime 246.55171265602112 seconds
# Total Billed Duration 1139.6 seconds
# Total Memory Used 45435 MB
# key spectra-1531763475.753800-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531763765.923038-1-1-1.ms2 last modified 1531763768000.0
# 13:56:45: Waiting for spectra function...
# 13:57:15: Waiting for spectra function...
# 13:57:46: Waiting for spectra function...
# 13:58:16: Waiting for spectra function...
# 13:58:46: Found spectra function
# 13:58:47: Waiting for percolator.decoy functions...
# 13:59:17: Waiting for percolator.decoy functions...
# 13:59:48: Waiting for percolator.decoy functions...
# 14:00:18: Found percolator.decoy functions
# 14:00:19: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531763877821
# Billed Duration 73000 milliseconds
# Max Memory Used 467
# Cost 0.00121691
#
# analyze_spectra
# Min Timestamp 1531763820510
# Max Timestamp 1531763898856
# Max Billed Duration 28800 milliseconds
# Total Billed Duration 1082100 milliseconds
# Cost 0.018038607
#
# Combine Spectra
# Timestamp 1531763899570
# Billed Duration 9100 milliseconds
# Max Memory Used 106
# Cost 3.7947e-05
#
# Percolator Spectra
# Timestamp 1531764010419
# Billed Duration 102000 milliseconds
# Max Memory Used 938
# Cost 0.00499494
#
# END RESULTS
# Total Cost 0.024288404000000003
# Total Runtime 251.66979994773865 seconds
# Total Billed Duration 1266.2 seconds
# Total Memory Used 45966 MB
# key spectra-1531763765.923038-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531764057.851201-1-1-1.ms2 last modified 1531764060000.0
# 14:01:36: Waiting for spectra function...
# 14:02:07: Waiting for spectra function...
# 14:02:37: Waiting for spectra function...
# 14:03:07: Waiting for spectra function...
# 14:03:38: Found spectra function
# 14:03:38: Waiting for percolator.decoy functions...
# 14:04:09: Waiting for percolator.decoy functions...
# 14:04:39: Waiting for percolator.decoy functions...
# 14:05:10: Found percolator.decoy functions
# 14:05:10: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531764167627
# Billed Duration 71500 milliseconds
# Max Memory Used 472
# Cost 0.001191905
#
# analyze_spectra
# Min Timestamp 1531764118360
# Max Timestamp 1531764186952
# Max Billed Duration 30400 milliseconds
# Total Billed Duration 1082300 milliseconds
# Cost 0.018041941000000002
#
# Combine Spectra
# Timestamp 1531764187345
# Billed Duration 8800 milliseconds
# Max Memory Used 107
# Cost 3.6696e-05
#
# Percolator Spectra
# Timestamp 1531764297096
# Billed Duration 102000 milliseconds
# Max Memory Used 938
# Cost 0.00499494
#
# END RESULTS
# Total Cost 0.024265482
# Total Runtime 250.92106623649596 seconds
# Total Billed Duration 1264.6 seconds
# Total Memory Used 46831 MB
# key spectra-1531764057.851201-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531764347.407523-1-1-1.ms2 last modified 1531764350000.0
# 14:06:26: Waiting for spectra function...
# 14:06:56: Waiting for spectra function...
# 14:07:27: Waiting for spectra function...
# 14:07:57: Waiting for spectra function...
# 14:08:28: Found spectra function
# 14:08:29: Waiting for percolator.decoy functions...
# 14:08:59: Waiting for percolator.decoy functions...
# 14:09:30: Waiting for percolator.decoy functions...
# 14:10:00: Found percolator.decoy functions
# 14:10:01: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531764464862
# Billed Duration 78800 milliseconds
# Max Memory Used 473
# Cost 0.001313596
#
# analyze_spectra
# Min Timestamp 1531764404828
# Max Timestamp 1531764484827
# Max Billed Duration 31300 milliseconds
# Total Billed Duration 1034700 milliseconds
# Cost 0.017248449000000003
#
# Combine Spectra
# Timestamp 1531764485215
# Billed Duration 9000 milliseconds
# Max Memory Used 122
# Cost 3.753e-05
#
# Percolator Spectra
# Timestamp 1531764594694
# Billed Duration 100700 milliseconds
# Max Memory Used 939
# Cost 0.004931279
#
# END RESULTS
# Total Cost 0.023530854000000004
# Total Runtime 258.27669100761415 seconds
# Total Billed Duration 1223.2 seconds
# Total Memory Used 47624 MB
# key spectra-1531764347.407523-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531764638.861650-1-1-1.ms2 last modified 1531764641000.0
# 14:11:18: Waiting for spectra function...
# 14:11:48: Waiting for spectra function...
# 14:12:19: Waiting for spectra function...
# 14:12:49: Waiting for spectra function...
# 14:13:20: Found spectra function
# 14:13:20: Waiting for percolator.decoy functions...
# 14:13:51: Waiting for percolator.decoy functions...
# 14:14:22: Waiting for percolator.decoy functions...
# 14:14:52: Waiting for percolator.decoy functions...
# 14:15:23: Found percolator.decoy functions
# 14:15:23: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531764764581
# Billed Duration 86300 milliseconds
# Max Memory Used 474
# Cost 0.0014386210000000002
#
# analyze_spectra
# Min Timestamp 1531764696684
# Max Timestamp 1531764785627
# Max Billed Duration 29500 milliseconds
# Total Billed Duration 1054600 milliseconds
# Cost 0.017580182
#
# Combine Spectra
# Timestamp 1531764785956
# Billed Duration 10200 milliseconds
# Max Memory Used 122
# Cost 4.2533999999999996e-05
#
# Percolator Spectra
# Timestamp 1531764897193
# Billed Duration 101300 milliseconds
# Max Memory Used 940
# Cost 0.004960661
#
# END RESULTS
# Total Cost 0.024021998000000003
# Total Runtime 266.32652764320375 seconds
# Total Billed Duration 1252.4 seconds
# Total Memory Used 47344 MB
# key spectra-1531764638.861650-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531764961.981352-1-1-1.ms2 last modified 1531764964000.0
# 14:16:41: Waiting for spectra function...
# 14:17:12: Waiting for spectra function...
# 14:17:42: Waiting for spectra function...
# 14:18:13: Waiting for spectra function...
# 14:18:43: Found spectra function
# 14:18:44: Waiting for percolator.decoy functions...
# 14:19:14: Waiting for percolator.decoy functions...
# 14:19:45: Waiting for percolator.decoy functions...
# 14:20:15: Found percolator.decoy functions
# 14:20:15: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531765083489
# Billed Duration 82100 milliseconds
# Max Memory Used 474
# Cost 0.001368607
#
# analyze_spectra
# Min Timestamp 1531765023747
# Max Timestamp 1531765104496
# Max Billed Duration 28500 milliseconds
# Total Billed Duration 1066600 milliseconds
# Cost 0.017780222000000002
#
# Combine Spectra
# Timestamp 1531765105010
# Billed Duration 8300 milliseconds
# Max Memory Used 114
# Cost 3.4611e-05
#
# Percolator Spectra
# Timestamp 1531765213760
# Billed Duration 100700 milliseconds
# Max Memory Used 941
# Cost 0.004931279
#
# END RESULTS
# Total Cost 0.024114719000000003
# Total Runtime 258.9037452697754 seconds
# Total Billed Duration 1257.7 seconds
# Total Memory Used 47024 MB
# key spectra-1531764961.981352-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531765255.554266-1-1-1.ms2 last modified 1531765258000.0
# 14:21:35: Waiting for spectra function...
# 14:22:06: Waiting for spectra function...
# 14:22:36: Waiting for spectra function...
# 14:23:07: Waiting for spectra function...
# 14:23:37: Found spectra function
# 14:23:38: Waiting for percolator.decoy functions...
# 14:24:08: Waiting for percolator.decoy functions...
# 14:24:39: Waiting for percolator.decoy functions...
# 14:25:09: Found percolator.decoy functions
# 14:25:10: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531765375208
# Billed Duration 79800 milliseconds
# Max Memory Used 474
# Cost 0.001330266
#
# analyze_spectra
# Min Timestamp 1531765315858
# Max Timestamp 1531765394454
# Max Billed Duration 28000 milliseconds
# Total Billed Duration 1060200 milliseconds
# Cost 0.017673534
#
# Combine Spectra
# Timestamp 1531765394789
# Billed Duration 9100 milliseconds
# Max Memory Used 106
# Cost 3.7947e-05
#
# Percolator Spectra
# Timestamp 1531765506219
# Billed Duration 101100 milliseconds
# Max Memory Used 939
# Cost 0.004950867
#
# END RESULTS
# Total Cost 0.023992614000000002
# Total Runtime 257.7693221569061 seconds
# Total Billed Duration 1250.2 seconds
# Total Memory Used 47127 MB
# key spectra-1531765255.554266-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# Uploading TN_CSF_062617_03.ms2 to S3
# spectra-1531765546.069392-1-1-1.ms2 last modified 1531765548000.0
# 14:27:22: Waiting for spectra function...
# 14:27:52: Waiting for spectra function...
# 14:28:22: Waiting for spectra function...
# 14:28:53: Waiting for spectra function...
# 14:29:23: Found spectra function
# 14:29:24: Waiting for percolator.decoy functions...
# 14:29:54: Waiting for percolator.decoy functions...
# 14:30:25: Waiting for percolator.decoy functions...
# 14:30:55: Found percolator.decoy functions
# 14:30:56: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531765707132
# Billed Duration 65500 milliseconds
# Max Memory Used 474
# Cost 0.0010918850000000001
#
# analyze_spectra
# Min Timestamp 1531765660744
# Max Timestamp 1531765726445
# Max Billed Duration 29300 milliseconds
# Total Billed Duration 1045000 milliseconds
# Cost 0.017420150000000002
#
# Combine Spectra
# Timestamp 1531765726793
# Billed Duration 10800 milliseconds
# Max Memory Used 107
# Cost 4.5036e-05
#
# Percolator Spectra
# Timestamp 1531765836363
# Billed Duration 99000 milliseconds
# Max Memory Used 946
# Cost 0.00484803
#
# END RESULTS
# Total Cost 0.023405101
# Total Runtime 300.15600357055666 seconds
# Total Billed Duration 1220.3 seconds
# Total Memory Used 48105 MB
# key spectra-1531765546.069392-1-1-1.txt num_lines 251407
# key percolator.target.peptides.txt qvalues 3183
# key percolator.target.psms.txt qvalues 7135
# Deleted 1 input objects
# Deleted 52 merge objects
# Deleted 52 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 44.49812388420105 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.0012819230000000001
# Total Runtime 76.9 seconds
# Total Billed Duration 76.9 seconds
# Total Memory Used 470.6 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.0175241708
# Total Runtime 29.1 seconds
# Total Billed Duration 1051.24 seconds
# Total Memory Used 44607.8 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 3.890609999999999e-05
# Total Runtime 9.33 seconds
# Total Billed Duration 9.33 seconds
# Total Memory Used 109.9 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0049489082
# Total Runtime 101.06 seconds
# Total Billed Duration 101.06 seconds
# Total Memory Used 938.0 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.0237939081
# Total Runtime 260.88812388420104 seconds
# Total Billed Duration 1238.53 seconds
# Total Memory Used 46126.3 MB

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large file, pre sort")

batch_size = 1000
params = {
  "input_name": "TN_CSF_062617_03.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 2048,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large file, pre sort
# Current Git commit 8a7c4cb lambda: Generalize more extension logic
#
#
# Iteration 0
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531775884.986080-1-1-1.mzML last modified 1531775887000.0
# 17:18:33: Waiting for spectra function...
# 17:19:04: Waiting for spectra function...
# 17:19:34: Waiting for spectra function...
# 17:20:05: Waiting for spectra function...
# 17:20:35: Waiting for spectra function...
# 17:21:05: Waiting for spectra function...
# 17:21:36: Found spectra function
# 17:21:36: Waiting for percolator.decoy functions...
# 17:22:07: Waiting for percolator.decoy functions...
# 17:22:37: Found percolator.decoy functions
# 17:22:38: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531776063903
# Billed Duration 150200 milliseconds
# Max Memory Used 1053
# Cost 0.005007668
#
# analyze_spectra
# Min Timestamp 1531775934783
# Max Timestamp 1531776072603
# Max Billed Duration 19500 milliseconds
# Total Billed Duration 925600 milliseconds
# Cost 0.015429752000000001
#
# Combine Spectra
# Timestamp 1531776072992
# Billed Duration 9200 milliseconds
# Max Memory Used 91
# Cost 3.8364e-05
#
# Percolator Spectra
# Timestamp 1531776168005
# Billed Duration 87100 milliseconds
# Max Memory Used 784
# Cost 0.0042652869999999996
#
# END RESULTS
# Total Cost 0.024741071
# Total Runtime 294.3697805404663 seconds
# Total Billed Duration 1172.1 seconds
# Total Memory Used 46949 MB
# key spectra-1531775884.986080-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531776197.933408-1-1-1.mzML last modified 1531776199000.0
# 17:23:46: Waiting for spectra function...
# 17:24:16: Waiting for spectra function...
# 17:24:46: Waiting for spectra function...
# 17:25:17: Waiting for spectra function...
# 17:25:48: Waiting for spectra function...
# 17:26:18: Waiting for spectra function...
# 17:26:49: Found spectra function
# 17:26:49: Waiting for percolator.decoy functions...
# 17:27:19: Waiting for percolator.decoy functions...
# 17:27:50: Found percolator.decoy functions
# 17:27:50: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531776374118
# Billed Duration 148500 milliseconds
# Max Memory Used 1112
# Cost 0.004950990000000001
#
# analyze_spectra
# Min Timestamp 1531776242792
# Max Timestamp 1531776382308
# Max Billed Duration 20200 milliseconds
# Total Billed Duration 920400 milliseconds
# Cost 0.015343068000000001
#
# Combine Spectra
# Timestamp 1531776382672
# Billed Duration 9500 milliseconds
# Max Memory Used 91
# Cost 3.9615e-05
#
# Percolator Spectra
# Timestamp 1531776475115
# Billed Duration 85200 milliseconds
# Max Memory Used 789
# Cost 0.004172244
#
# END RESULTS
# Total Cost 0.024505917000000002
# Total Runtime 290.98801627159116 seconds
# Total Billed Duration 1163.6 seconds
# Total Memory Used 47941 MB
# key spectra-1531776197.933408-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531776510.961656-1-1-1.mzML last modified 1531776512000.0
# 17:28:49: Waiting for spectra function...
# 17:29:20: Waiting for spectra function...
# 17:29:50: Waiting for spectra function...
# 17:30:21: Waiting for spectra function...
# 17:30:51: Waiting for spectra function...
# 17:31:22: Waiting for spectra function...
# 17:31:52: Found spectra function
# 17:31:53: Waiting for percolator.decoy functions...
# 17:32:23: Waiting for percolator.decoy functions...
# 17:32:53: Waiting for percolator.decoy functions...
# 17:33:24: Found percolator.decoy functions
# 17:33:24: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531776681183
# Billed Duration 152300 milliseconds
# Max Memory Used 1112
# Cost 0.005077682
#
# analyze_spectra
# Min Timestamp 1531776546484
# Max Timestamp 1531776689024
# Max Billed Duration 21700 milliseconds
# Total Billed Duration 900100 milliseconds
# Cost 0.015004667000000001
#
# Combine Spectra
# Timestamp 1531776689252
# Billed Duration 9700 milliseconds
# Max Memory Used 92
# Cost 4.0449e-05
#
# Percolator Spectra
# Timestamp 1531776782775
# Billed Duration 85300 milliseconds
# Max Memory Used 792
# Cost 0.004177141
#
# END RESULTS
# Total Cost 0.024299939
# Total Runtime 286.8565936088562 seconds
# Total Billed Duration 1147.4 seconds
# Total Memory Used 48096 MB
# key spectra-1531776510.961656-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531776847.080937-1-1-1.mzML last modified 1531776849000.0
# 17:34:26: Waiting for spectra function...
# 17:34:57: Waiting for spectra function...
# 17:35:28: Waiting for spectra function...
# 17:35:58: Waiting for spectra function...
# 17:36:28: Waiting for spectra function...
# 17:36:59: Waiting for spectra function...
# 17:37:29: Found spectra function
# 17:37:30: Waiting for percolator.decoy functions...
# 17:38:00: Waiting for percolator.decoy functions...
# 17:38:31: Found percolator.decoy functions
# 17:38:31: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531777013997
# Billed Duration 148200 milliseconds
# Max Memory Used 1112
# Cost 0.004940988
#
# analyze_spectra
# Min Timestamp 1531776884166
# Max Timestamp 1531777021463
# Max Billed Duration 20300 milliseconds
# Total Billed Duration 927100 milliseconds
# Cost 0.015454757000000001
#
# Combine Spectra
# Timestamp 1531777021715
# Billed Duration 8800 milliseconds
# Max Memory Used 92
# Cost 3.6696e-05
#
# Percolator Spectra
# Timestamp 1531777113572
# Billed Duration 84300 milliseconds
# Max Memory Used 793
# Cost 0.004128171
#
# END RESULTS
# Total Cost 0.024560612
# Total Runtime 280.1558812618256 seconds
# Total Billed Duration 1168.4 seconds
# Total Memory Used 48078 MB
# key spectra-1531776847.080937-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531777154.719454-1-1-1.mzML last modified 1531777156000.0
# 17:39:33: Waiting for spectra function...
# 17:40:03: Waiting for spectra function...
# 17:40:34: Waiting for spectra function...
# 17:41:04: Waiting for spectra function...
# 17:41:35: Waiting for spectra function...
# 17:42:05: Waiting for spectra function...
# 17:42:35: Waiting for spectra function...
# 17:43:06: Waiting for spectra function...
# 17:43:36: Waiting for spectra function...
# 17:44:06: Waiting for spectra function...
# 17:44:37: Found spectra function
# 17:44:37: Waiting for percolator.decoy functions...
# 17:45:08: Waiting for percolator.decoy functions...
# 17:45:38: Found percolator.decoy functions
# 17:45:39: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531777325438
# Billed Duration 152400 milliseconds
# Max Memory Used 1112
# Cost 0.005081016000000001
#
# analyze_spectra
# Min Timestamp 1531777193028
# Max Timestamp 1531777447300
# Max Billed Duration 20800 milliseconds
# Total Billed Duration 992500 milliseconds
# Cost 0.016544975
#
# Combine Spectra
# Timestamp 1531777447807
# Billed Duration 9000 milliseconds
# Max Memory Used 94
# Cost 3.753e-05
#
# Percolator Spectra
# Timestamp 1531777531544
# Billed Duration 75000 milliseconds
# Max Memory Used 793
# Cost 0.00367275
#
# END RESULTS
# Total Cost 0.025336271
# Total Runtime 275.4108061313629 seconds
# Total Billed Duration 1228.9 seconds
# Total Memory Used 48127 MB
# key spectra-1531777154.719454-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531777579.722274-1-1-1.mzML last modified 1531777581000.0
# 17:46:38: Waiting for spectra function...
# 17:47:08: Waiting for spectra function...
# 17:47:39: Waiting for spectra function...
# 17:48:10: Waiting for spectra function...
# 17:48:40: Waiting for spectra function...
# 17:49:11: Waiting for spectra function...
# 17:49:41: Waiting for spectra function...
# 17:50:12: Found spectra function
# 17:50:12: Waiting for percolator.decoy functions...
# 17:50:43: Waiting for percolator.decoy functions...
# 17:51:13: Found percolator.decoy functions
# 17:51:14: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531777778186
# Billed Duration 180500 milliseconds
# Max Memory Used 1113
# Cost 0.006017870000000001
#
# analyze_spectra
# Min Timestamp 1531777615937
# Max Timestamp 1531777786382
# Max Billed Duration 19700 milliseconds
# Total Billed Duration 958800 milliseconds
# Cost 0.015983196
#
# Combine Spectra
# Timestamp 1531777786848
# Billed Duration 8200 milliseconds
# Max Memory Used 94
# Cost 3.4194e-05
#
# Percolator Spectra
# Timestamp 1531777870078
# Billed Duration 75400 milliseconds
# Max Memory Used 795
# Cost 0.003692338
#
# END RESULTS
# Total Cost 0.025727598000000004
# Total Runtime 301.6224632740021 seconds
# Total Billed Duration 1222.9 seconds
# Total Memory Used 48209 MB
# key spectra-1531777579.722274-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531777913.988325-1-1-1.mzML last modified 1531777915000.0
# 17:52:45: Waiting for spectra function...
# 17:53:15: Waiting for spectra function...
# 17:53:45: Waiting for spectra function...
# 17:54:16: Waiting for spectra function...
# 17:54:46: Waiting for spectra function...
# 17:55:17: Waiting for spectra function...
# 17:55:47: Found spectra function
# 17:55:47: Waiting for percolator.decoy functions...
# 17:56:18: Waiting for percolator.decoy functions...
# 17:56:48: Found percolator.decoy functions
# 17:56:49: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531778112810
# Billed Duration 148000 milliseconds
# Max Memory Used 1113
# Cost 0.00493432
#
# analyze_spectra
# Min Timestamp 1531777982866
# Max Timestamp 1531778121005
# Max Billed Duration 19700 milliseconds
# Total Billed Duration 934300 milliseconds
# Cost 0.015574781000000001
#
# Combine Spectra
# Timestamp 1531778121407
# Billed Duration 7500 milliseconds
# Max Memory Used 94
# Cost 3.1275e-05
#
# Percolator Spectra
# Timestamp 1531778204550
# Billed Duration 76000 milliseconds
# Max Memory Used 795
# Cost 0.00372172
#
# END RESULTS
# Total Cost 0.024262096000000004
# Total Runtime 301.8738953590393 seconds
# Total Billed Duration 1165.8 seconds
# Total Memory Used 48306 MB
# key spectra-1531777913.988325-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531778248.886167-1-1-1.mzML last modified 1531778250000.0
# 17:57:46: Waiting for spectra function...
# 17:58:16: Waiting for spectra function...
# 17:58:47: Waiting for spectra function...
# 17:59:17: Waiting for spectra function...
# 17:59:48: Waiting for spectra function...
# 18:00:18: Waiting for spectra function...
# 18:00:49: Found spectra function
# 18:00:49: Waiting for percolator.decoy functions...
# 18:01:19: Waiting for percolator.decoy functions...
# 18:01:50: Waiting for percolator.decoy functions...
# 18:02:20: Found percolator.decoy functions
# 18:02:21: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531778419362
# Billed Duration 153200 milliseconds
# Max Memory Used 1113
# Cost 0.005107688
#
# analyze_spectra
# Min Timestamp 1531778283863
# Max Timestamp 1531778427598
# Max Billed Duration 19700 milliseconds
# Total Billed Duration 937400 milliseconds
# Cost 0.015626458
#
# Combine Spectra
# Timestamp 1531778427972
# Billed Duration 10400 milliseconds
# Max Memory Used 91
# Cost 4.3367999999999995e-05
#
# Percolator Spectra
# Timestamp 1531778513771
# Billed Duration 75700 milliseconds
# Max Memory Used 796
# Cost 0.0037070289999999997
#
# END RESULTS
# Total Cost 0.024484542999999998
# Total Runtime 276.16319465637207 seconds
# Total Billed Duration 1176.7 seconds
# Total Memory Used 48459 MB
# key spectra-1531778248.886167-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531778580.819599-1-1-1.mzML last modified 1531778582000.0
# 18:03:19: Waiting for spectra function...
# 18:03:49: Waiting for spectra function...
# 18:04:19: Waiting for spectra function...
# 18:04:50: Waiting for spectra function...
# 18:05:20: Waiting for spectra function...
# 18:05:51: Waiting for spectra function...
# 18:06:21: Waiting for spectra function...
# 18:06:51: Found spectra function
# 18:06:52: Waiting for percolator.decoy functions...
# 18:07:22: Waiting for percolator.decoy functions...
# 18:07:53: Waiting for percolator.decoy functions...
# 18:08:23: Found percolator.decoy functions
# 18:08:24: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531778746261
# Billed Duration 147700 milliseconds
# Max Memory Used 1113
# Cost 0.0049243180000000004
#
# analyze_spectra
# Min Timestamp 1531778616964
# Max Timestamp 1531778790384
# Max Billed Duration 19200 milliseconds
# Total Billed Duration 920700 milliseconds
# Cost 0.015348069
#
# Combine Spectra
# Timestamp 1531778790912
# Billed Duration 11100 milliseconds
# Max Memory Used 91
# Cost 4.6287e-05
#
# Percolator Spectra
# Timestamp 1531778876978
# Billed Duration 75400 milliseconds
# Max Memory Used 797
# Cost 0.003692338
#
# END RESULTS
# Total Cost 0.024011012
# Total Runtime 271.0809351444244 seconds
# Total Billed Duration 1154.9 seconds
# Total Memory Used 48467 MB
# key spectra-1531778580.819599-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# Uploading TN_CSF_062617_03.mzML to S3
# spectra-1531778943.439362-1-1-1.mzML last modified 1531778945000.0
# 18:09:21: Waiting for spectra function...
# 18:09:51: Waiting for spectra function...
# 18:10:22: Waiting for spectra function...
# 18:10:52: Waiting for spectra function...
# 18:11:23: Waiting for spectra function...
# 18:11:53: Waiting for spectra function...
# 18:12:23: Found spectra function
# 18:12:24: Waiting for percolator.decoy functions...
# 18:12:54: Waiting for percolator.decoy functions...
# 18:13:25: Waiting for percolator.decoy functions...
# 18:13:55: Found percolator.decoy functions
# 18:13:56: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531779112127
# Billed Duration 151100 milliseconds
# Max Memory Used 1114
# Cost 0.005037674000000001
#
# analyze_spectra
# Min Timestamp 1531778978545
# Max Timestamp 1531779120467
# Max Billed Duration 20500 milliseconds
# Total Billed Duration 921500 milliseconds
# Cost 0.015361405000000002
#
# Combine Spectra
# Timestamp 1531779120812
# Billed Duration 11100 milliseconds
# Max Memory Used 91
# Cost 4.6287e-05
#
# Percolator Spectra
# Timestamp 1531779222219
# Billed Duration 88500 milliseconds
# Max Memory Used 795
# Cost 0.004333845
#
# END RESULTS
# Total Cost 0.024779211
# Total Runtime 288.6788076877594 seconds
# Total Billed Duration 1172.2 seconds
# Total Memory Used 48512 MB
# key spectra-1531778943.439362-1-1-1.txt num_lines 207821
# key percolator.target.peptides.txt qvalues 3240
# key percolator.target.psms.txt qvalues 7132
# Deleted 1 input objects
# Deleted 67 merge objects
# Deleted 67 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 23.140037393569948 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.005108021400000001
# Total Runtime 153.21 seconds
# Total Billed Duration 153.21 seconds
# Total Memory Used 1106.7 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.0155671128
# Total Runtime 20.13 seconds
# Total Billed Duration 933.84 seconds
# Total Memory Used 46122.7 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 3.9406499999999996e-05
# Total Runtime 9.45 seconds
# Total Billed Duration 9.45 seconds
# Total Memory Used 92.1 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0039562863
# Total Runtime 80.79 seconds
# Total Billed Duration 80.79 seconds
# Total Memory Used 792.9 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.024670827
# Total Runtime 286.72003739356995 seconds
# Total Billed Duration 1177.29 seconds
# Total Memory Used 48114.4 MB

# %%
import subprocess
from subprocess import Popen, PIPE, STDOUT


print(subprocess.check_output('cat TN_CSF_062617_03.mzML | grep "<spectrum index" | wc -l', shell=True))
print(subprocess.check_output('cat TN_CSF_062617_03.ms2 | grep "S\s" | wc -l', shell=True))
f = open("TN_CSF_062617_03.mzML")
lines = f.readlines()[0:100]
print(len("".join(lines)))
print("")
f = open("ASH_20170314_HELA_90MIN_20170320042659.mzML")
lines = f.readlines()[0:100]
print(len("".join(lines)))


#cmd = './crux tide-search empty.mzML HUMAN.fasta.20170123.index --overwrite T'
#p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
#print(p.stdout.read())
#print(p.stderr.read())
# Out:
# b'66667\n'
# b'51322\n'
# 12835
#
# 6634

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 8000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 1000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531835971.767801-1-1-1.mzML last modified 1531835976000.0
# 10:00:45: Waiting for spectra function. Split 0 Analyze 0.
# 10:01:17: Waiting for spectra function. Split 1 Analyze 0.
# 10:01:48: Waiting for spectra function. Split 2 Analyze 1.
# 10:02:19: Waiting for spectra function. Split 3 Analyze 2.
# 10:02:50: Waiting for spectra function. Split 5 Analyze 3.
# 10:03:22: Waiting for spectra function. Split 6 Analyze 4.
# 10:03:53: Waiting for spectra function. Split 7 Analyze 6.
# 10:04:24: Waiting for spectra function. Split 8 Analyze 6.
# 10:04:56: Waiting for spectra function. Split 9 Analyze 8.
# 10:05:27: Waiting for spectra function. Split 10 Analyze 8.
# 10:05:58: Waiting for spectra function. Split 11 Analyze 10.
# 10:06:30: Waiting for spectra function. Split 11 Analyze 11.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-719c81f0aac1> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 16000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 5000000,
    "memory_size": 2048,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531836597.250751-1-1-1.mzML last modified 1531836601000.0
# 10:11:09: Waiting for spectra function. Split 0 Analyze 0.
# 10:11:41: Waiting for spectra function. Split 1 Analyze 0.
# 10:12:12: Waiting for spectra function. Split 2 Analyze 0.
# 10:12:43: Waiting for spectra function. Split 3 Analyze 1.
# 10:13:14: Waiting for spectra function. Split 4 Analyze 1.
# 10:13:45: Waiting for spectra function. Split 5 Analyze 2.
# 10:14:17: Waiting for spectra function. Split 6 Analyze 2.
# 10:14:48: Waiting for spectra function. Split 7 Analyze 4.
# 10:15:20: Waiting for spectra function. Split 7 Analyze 5.
# 10:15:51: Waiting for spectra function. Split 8 Analyze 5.
# 10:16:23: Waiting for spectra function. Split 9 Analyze 5.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-be6ae083ff38> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 32000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 5000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531837050.862582-1-1-1.mzML last modified 1531837055000.0
# 10:19:17: Waiting for spectra function. Split 0 Analyze 0.
# 10:19:48: Waiting for spectra function. Split 0 Analyze 0.
# 10:20:20: Waiting for spectra function. Split 1 Analyze 0.
# 10:20:51: Waiting for spectra function. Split 1 Analyze 0.
# 10:21:22: Waiting for spectra function. Split 1 Analyze 0.
# 10:21:54: Waiting for spectra function. Split 1 Analyze 0.
# 10:22:25: Waiting for spectra function. Split 1 Analyze 0.
# 10:22:56: Waiting for spectra function. Split 1 Analyze 0.
# 10:23:28: Waiting for spectra function. Split 1 Analyze 0.
# 10:23:59: Waiting for spectra function. Split 1 Analyze 0.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-45f5ac960951> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 16000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 5000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531837479.320619-1-1-1.mzML last modified 1531837484000.0
# 10:25:52: Waiting for spectra function. Split 0 Analyze 0.
# 10:26:23: Waiting for spectra function. Split 1 Analyze 0.
# 10:26:54: Waiting for spectra function. Split 2 Analyze 0.
# 10:27:25: Waiting for spectra function. Split 3 Analyze 1.
# 10:27:57: Waiting for spectra function. Split 4 Analyze 2.
# 10:28:28: Waiting for spectra function. Split 5 Analyze 3.
# 10:28:59: Waiting for spectra function. Split 6 Analyze 4.
# 10:29:31: Waiting for spectra function. Split 7 Analyze 4.
# 10:30:02: Waiting for spectra function. Split 8 Analyze 4.
# 10:30:34: Waiting for spectra function. Split 9 Analyze 4.
# 10:31:05: Waiting for spectra function. Split 9 Analyze 4.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-79748b155632> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 20000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 3008,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531839174.384195-1-1-1.mzML last modified 1531839179000.0
# 10:54:07: Waiting for spectra function. Split 0 Analyze 0.
# 10:54:38: Waiting for spectra function. Split 1 Analyze 0.
# 10:55:09: Waiting for spectra function. Split 2 Analyze 1.
# 10:55:41: Waiting for spectra function. Split 3 Analyze 1.
# 10:56:13: Waiting for spectra function. Split 3 Analyze 1.
# 10:56:44: Waiting for spectra function. Split 4 Analyze 1.
# 10:57:15: Waiting for spectra function. Split 5 Analyze 1.
# 10:57:47: Waiting for spectra function. Split 7 Analyze 2.
# 10:58:18: Waiting for spectra function. Split 7 Analyze 2.
# 10:58:50: Waiting for spectra function. Split 7 Analyze 2.
# 10:59:21: Waiting for spectra function. Split 7 Analyze 2.
# 10:59:52: Waiting for spectra function. Split 7 Analyze 2.
# 11:00:23: Waiting for spectra function. Split 7 Analyze 2.
# 11:00:55: Waiting for spectra function. Split 7 Analyze 2.
# 11:01:26: Waiting for spectra function. Split 7 Analyze 2.
# 11:01:57: Waiting for spectra function. Split 7 Analyze 2.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-94d59a431ec7> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")

batch_size = 20000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 3008,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit bc152c1 spectra: Use deterministic header
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531839813.552506-1-1-1.mzML last modified 1531839818000.0
# 11:04:48: Waiting for spectra function. Split 0 Analyze 0.
# 11:05:19: Waiting for spectra function. Split 1 Analyze 0.
# 11:05:50: Waiting for spectra function. Split 1 Analyze 1.
# 11:06:21: Waiting for spectra function. Split 3 Analyze 1.
# 11:06:52: Waiting for spectra function. Split 3 Analyze 1.
# 11:07:24: Waiting for spectra function. Split 4 Analyze 1.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-cd2920d1adcd> in <module>()
#      75 }
#      76
# ---> 77 benchmark.run(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in run(params)
#     200       try:
#     201         if params["lambda"]:
# --> 202           results = lambda_benchmark(params)
#     203         else:
#     204           results = ec2_benchmark(params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in lambda_benchmark(params)
#     635 def lambda_benchmark(params):
#     636   [upload_timestamp, upload_duration] = upload_input(params)
# --> 637   wait_for_completion(upload_timestamp, params)
#     638   return parse_logs(params, upload_timestamp, upload_duration)
#     639
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in wait_for_completion(start_time, params)
#     419   overhead = 3.5  # Give ourselves time as we need to wait for the split and analyze functions to finish.
#     420   bucket_name = "maccoss-human-combine-spectra"
# --> 421   check_objects(client, bucket_name, "spectra", 1, params["combine_spectra_results"]["timeout"] * overhead, params)
#     422   bucket_name = "maccoss-human-output-spectra"
#     423   check_objects(client, bucket_name, "percolator.decoy", 2,  params["percolator"]["timeout"] * overhead, params)
#
# ~/Research/Hakim/Serverless/serverless/benchmark.py in check_objects(client, bucket_name, prefix, count, timeout, params)
#     409       if (end - start).total_seconds() > timeout:
#     410         raise BenchmarkException("Could not find bucket {0:s} prefix {1:s}".format(bucket_name, prefix))
# --> 411       time.sleep(30)
#     412     else:
#     413       print("{0:s}: Found {1:s} function{2:s}".format(now, prefix, suffix))
#
# KeyboardInterrupt:

# %%
import constants
import util
import sort
import benchmark
import importlib
import subprocess
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")
subprocess.call("python3 test.py", shell=True)

batch_size = 16000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": True,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.2xlarge",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 3008,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit f3c1e49 lambda: Allow splits in analysis function
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531865625.620313-1-0-1-1.mzML last modified 1531865630000.0
# 18:14:57: Waiting for spectra function. Split 0 Analyze 0.
# 18:15:28: Waiting for spectra function. Split 1 Analyze 0.
# 18:16:00: Waiting for spectra function. Split 2 Analyze 1.
# 18:16:32: Waiting for spectra function. Split 3 Analyze 2.
# 18:17:03: Waiting for spectra function. Split 4 Analyze 3.
# 18:17:34: Waiting for spectra function. Split 5 Analyze 4.
# 18:18:06: Waiting for spectra function. Split 6 Analyze 5.
# 18:18:37: Waiting for spectra function. Split 7 Analyze 6.
# 18:19:08: Waiting for spectra function. Split 9 Analyze 8.
# 18:19:39: Waiting for spectra function. Split 10 Analyze 8.
# 18:20:11: Waiting for spectra function. Split 11 Analyze 10.
# 18:20:42: Found spectra function
# 18:20:43: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:21:14: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:21:45: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:22:17: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:22:48: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:23:19: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:23:50: Found percolator.decoy functions
# 18:23:51: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531865940095
# Billed Duration 242500 milliseconds
# Max Memory Used 1744
# Cost 0.011875225
#
# analyze_spectra
# Min Timestamp 1531865748820
# Max Timestamp 1531865998979
# Min Memory 968
# Max Memory 1650
# Max Billed Duration 40500 milliseconds
# Total Billed Duration 288900 milliseconds
# Cost 0.014147433
#
# Combine Spectra
# Timestamp 1531865999216
# Billed Duration 15800 milliseconds
# Max Memory Used 247
# Cost 6.5886e-05
#
# Percolator Spectra
# Timestamp 1531866227016
# Billed Duration 211700 milliseconds
# Max Memory Used 2094
# Cost 0.010366949
#
# END RESULTS
# Total Cost 0.036455493
# Total Runtime 582.0238139629364 seconds
# Total Billed Duration 758.9 seconds
# Total Memory Used 18926 MB
# key percolator.target.peptides.txt qvalues 25366
# key percolator.target.psms.txt qvalues 36549
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531866256.934439-1-0-1-1.mzML last modified 1531866261000.0
# 18:25:27: Waiting for spectra function. Split 0 Analyze 0.
# 18:25:59: Waiting for spectra function. Split 1 Analyze 0.
# 18:26:30: Waiting for spectra function. Split 2 Analyze 1.
# 18:27:01: Waiting for spectra function. Split 3 Analyze 1.
# 18:27:32: Waiting for spectra function. Split 4 Analyze 2.
# 18:28:04: Waiting for spectra function. Split 5 Analyze 4.
# 18:28:35: Waiting for spectra function. Split 6 Analyze 5.
# 18:29:06: Waiting for spectra function. Split 6 Analyze 6.
# 18:29:37: Waiting for spectra function. Split 7 Analyze 6.
# 18:30:09: Waiting for spectra function. Split 9 Analyze 8.
# 18:30:40: Waiting for spectra function. Split 11 Analyze 9.
# 18:31:12: Found spectra function
# 18:31:12: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:31:43: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:32:15: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:32:46: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:33:17: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:33:48: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:34:20: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:34:51: Found percolator.decoy functions
# 18:34:52: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531866584655
# Billed Duration 257100 milliseconds
# Max Memory Used 1744
# Cost 0.012590187
#
# analyze_spectra
# Min Timestamp 1531866378694
# Max Timestamp 1531866643853
# Min Memory 1164
# Max Memory 1653
# Max Billed Duration 41100 milliseconds
# Total Billed Duration 288700 milliseconds
# Cost 0.014137639
#
# Combine Spectra
# Timestamp 1531866644092
# Billed Duration 15600 milliseconds
# Max Memory Used 247
# Cost 6.5052e-05
#
# Percolator Spectra
# Timestamp 1531866870310
# Billed Duration 210700 milliseconds
# Max Memory Used 2099
# Cost 0.010317979
#
# END RESULTS
# Total Cost 0.037110857
# Total Runtime 595.004885673523 seconds
# Total Billed Duration 772.1 seconds
# Total Memory Used 19391 MB
# key percolator.target.peptides.txt qvalues 25366
# key percolator.target.psms.txt qvalues 36549
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531866918.011472-1-0-1-1.mzML last modified 1531866922000.0
# 18:36:32: Waiting for spectra function. Split 0 Analyze 0.
# 18:37:03: Waiting for spectra function. Split 1 Analyze 0.
# 18:37:34: Waiting for spectra function. Split 2 Analyze 1.
# 18:38:05: Waiting for spectra function. Split 3 Analyze 2.
# 18:38:36: Waiting for spectra function. Split 4 Analyze 3.
# 18:39:08: Waiting for spectra function. Split 5 Analyze 4.
# 18:39:39: Waiting for spectra function. Split 6 Analyze 5.
# 18:40:10: Waiting for spectra function. Split 7 Analyze 6.
# 18:40:42: Waiting for spectra function. Split 9 Analyze 8.
# 18:41:13: Waiting for spectra function. Split 11 Analyze 8.
# 18:41:44: Found spectra function
# 18:41:45: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:42:16: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:42:47: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:43:19: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:43:50: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:44:21: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:44:52: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:45:24: Found percolator.decoy functions
# 18:45:24: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531867226807
# Billed Duration 235100 milliseconds
# Max Memory Used 1744
# Cost 0.011512847
#
# analyze_spectra
# Min Timestamp 1531867042385
# Max Timestamp 1531867274953
# Min Memory 640
# Max Memory 1825
# Max Billed Duration 40200 milliseconds
# Total Billed Duration 281200 milliseconds
# Cost 0.013770364
#
# Combine Spectra
# Timestamp 1531867284639
# Billed Duration 14100 milliseconds
# Max Memory Used 247
# Cost 5.8797e-05
#
# Percolator Spectra
# Timestamp 1531867509497
# Billed Duration 210900 milliseconds
# Max Memory Used 2099
# Cost 0.010327773
#
# END RESULTS
# Total Cost 0.035669781
# Total Runtime 573.8961272716522 seconds
# Total Billed Duration 741.3 seconds
# Total Memory Used 19181 MB
# key percolator.target.peptides.txt qvalues 25350
# key percolator.target.psms.txt qvalues 36645
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531867548.981868-1-0-1-1.mzML last modified 1531867553000.0
# 18:47:00: Waiting for spectra function. Split 0 Analyze 0.
# 18:47:31: Waiting for spectra function. Split 1 Analyze 0.
# 18:48:03: Waiting for spectra function. Split 2 Analyze 1.
# 18:48:34: Waiting for spectra function. Split 3 Analyze 2.
# 18:49:05: Waiting for spectra function. Split 4 Analyze 3.
# 18:49:36: Waiting for spectra function. Split 5 Analyze 4.
# 18:50:08: Waiting for spectra function. Split 6 Analyze 5.
# 18:50:39: Waiting for spectra function. Split 7 Analyze 6.
# 18:51:11: Waiting for spectra function. Split 9 Analyze 8.
# 18:51:42: Waiting for spectra function. Split 11 Analyze 8.
# 18:52:13: Found spectra function
# 18:52:14: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:52:45: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:53:16: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:53:48: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:54:19: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:54:50: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:55:21: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 18:55:53: Found percolator.decoy functions
# 18:55:53: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531867857303
# Billed Duration 237000 milliseconds
# Max Memory Used 1744
# Cost 0.011605889999999999
#
# analyze_spectra
# Min Timestamp 1531867672075
# Max Timestamp 1531867916217
# Min Memory 1148
# Max Memory 1888
# Max Billed Duration 34900 milliseconds
# Total Billed Duration 265800 milliseconds
# Cost 0.013016225999999999
#
# Combine Spectra
# Timestamp 1531867916539
# Billed Duration 13500 milliseconds
# Max Memory Used 248
# Cost 5.6294999999999995e-05
#
# Percolator Spectra
# Timestamp 1531868139623
# Billed Duration 209600 milliseconds
# Max Memory Used 2099
# Cost 0.010264112
#
# END RESULTS
# Total Cost 0.034942523
# Total Runtime 566.2584733963013 seconds
# Total Billed Duration 725.9 seconds
# Total Memory Used 20597 MB
# key percolator.target.peptides.txt qvalues 25331
# key percolator.target.psms.txt qvalues 36676
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531868180.752112-1-0-1-1.mzML last modified 1531868185000.0
# 18:57:47: Waiting for spectra function. Split 0 Analyze 0.
# 18:58:18: Waiting for spectra function. Split 1 Analyze 0.
# 18:58:49: Waiting for spectra function. Split 2 Analyze 1.
# 18:59:21: Waiting for spectra function. Split 3 Analyze 2.
# 18:59:52: Waiting for spectra function. Split 4 Analyze 3.
# 19:00:24: Waiting for spectra function. Split 5 Analyze 4.
# 19:00:55: Waiting for spectra function. Split 6 Analyze 5.
# 19:01:27: Waiting for spectra function. Split 7 Analyze 6.
# 19:01:58: Waiting for spectra function. Split 9 Analyze 7.
# 19:02:29: Waiting for spectra function. Split 10 Analyze 8.
# 19:03:00: Waiting for spectra function. Split 11 Analyze 10.
# 19:03:32: Found spectra function
# 19:03:32: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:04:04: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:04:35: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:05:06: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:05:37: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:06:08: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:06:40: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:07:11: Found percolator.decoy functions
# 19:07:11: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531868516621
# Billed Duration 249500 milliseconds
# Max Memory Used 1744
# Cost 0.012218015
#
# analyze_spectra
# Min Timestamp 1531868319954
# Max Timestamp 1531868564747
# Min Memory 642
# Max Memory 1933
# Max Billed Duration 42700 milliseconds
# Total Billed Duration 290700 milliseconds
# Cost 0.014235579
#
# Combine Spectra
# Timestamp 1531868577978
# Billed Duration 15300 milliseconds
# Max Memory Used 256
# Cost 6.3801e-05
#
# Percolator Spectra
# Timestamp 1531868806041
# Billed Duration 212900 milliseconds
# Max Memory Used 2100
# Cost 0.010425713
#
# END RESULTS
# Total Cost 0.036943108
# Total Runtime 606.6563614845276 seconds
# Total Billed Duration 768.4 seconds
# Total Memory Used 20747 MB
# key percolator.target.peptides.txt qvalues 25426
# key percolator.target.psms.txt qvalues 36552
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531868857.045986-1-0-1-1.mzML last modified 1531868861000.0
# 19:08:47: Waiting for spectra function. Split 0 Analyze 0.
# 19:09:18: Waiting for spectra function. Split 1 Analyze 0.
# 19:09:49: Waiting for spectra function. Split 2 Analyze 1.
# 19:10:20: Waiting for spectra function. Split 3 Analyze 2.
# 19:10:52: Waiting for spectra function. Split 4 Analyze 3.
# 19:11:23: Waiting for spectra function. Split 5 Analyze 4.
# 19:11:54: Waiting for spectra function. Split 6 Analyze 5.
# 19:12:26: Waiting for spectra function. Split 7 Analyze 6.
# 19:12:57: Waiting for spectra function. Split 9 Analyze 8.
# 19:13:28: Waiting for spectra function. Split 10 Analyze 8.
# 19:14:00: Waiting for spectra function. Split 11 Analyze 10.
# 19:14:31: Found spectra function
# 19:14:32: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:15:03: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:15:35: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:16:06: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:16:37: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:17:08: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:17:40: Found percolator.decoy functions
# 19:17:40: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531869173735
# Billed Duration 247100 milliseconds
# Max Memory Used 1744
# Cost 0.012100487
#
# analyze_spectra
# Min Timestamp 1531868979190
# Max Timestamp 1531869232962
# Min Memory 1150
# Max Memory 1968
# Max Billed Duration 41300 milliseconds
# Total Billed Duration 286600 milliseconds
# Cost 0.014034801999999999
#
# Combine Spectra
# Timestamp 1531869233233
# Billed Duration 13800 milliseconds
# Max Memory Used 256
# Cost 5.7546e-05
#
# Percolator Spectra
# Timestamp 1531869458942
# Billed Duration 212000 milliseconds
# Max Memory Used 2100
# Cost 0.01038164
#
# END RESULTS
# Total Cost 0.036574474999999995
# Total Runtime 583.6948287010193 seconds
# Total Billed Duration 759.5 seconds
# Total Memory Used 20569 MB
# key percolator.target.peptides.txt qvalues 25286
# key percolator.target.psms.txt qvalues 36630
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531869484.488949-1-0-1-1.mzML last modified 1531869489000.0
# 19:19:15: Waiting for spectra function. Split 0 Analyze 0.
# 19:19:46: Waiting for spectra function. Split 1 Analyze 0.
# 19:20:17: Waiting for spectra function. Split 2 Analyze 1.
# 19:20:48: Waiting for spectra function. Split 3 Analyze 2.
# 19:21:19: Waiting for spectra function. Split 4 Analyze 3.
# 19:21:51: Waiting for spectra function. Split 5 Analyze 4.
# 19:22:22: Waiting for spectra function. Split 6 Analyze 5.
# 19:22:54: Waiting for spectra function. Split 7 Analyze 6.
# 19:23:25: Waiting for spectra function. Split 9 Analyze 8.
# 19:23:56: Waiting for spectra function. Split 11 Analyze 8.
# 19:24:27: Found spectra function
# 19:24:28: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:24:59: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:25:30: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:26:02: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:26:33: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:27:24: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:27:55: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:28:27: Found percolator.decoy functions
# 19:28:27: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531869797479
# Billed Duration 242700 milliseconds
# Max Memory Used 1744
# Cost 0.011885019
#
# analyze_spectra
# Min Timestamp 1531869608696
# Max Timestamp 1531869841329
# Min Memory 1514
# Max Memory 1968
# Max Billed Duration 34900 milliseconds
# Total Billed Duration 280500 milliseconds
# Cost 0.013736085
#
# Combine Spectra
# Timestamp 1531869850199
# Billed Duration 14000 milliseconds
# Max Memory Used 256
# Cost 5.838e-05
#
# Percolator Spectra
# Timestamp 1531870078133
# Billed Duration 214200 milliseconds
# Max Memory Used 2100
# Cost 0.010489374
#
# END RESULTS
# Total Cost 0.036168858
# Total Runtime 575.7956502914428 seconds
# Total Billed Duration 751.4 seconds
# Total Memory Used 21805 MB
# key percolator.target.peptides.txt qvalues 25331
# key percolator.target.psms.txt qvalues 36676
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531870132.570906-1-0-1-1.mzML last modified 1531870137000.0
# 19:30:13: Waiting for spectra function. Split 0 Analyze 0.
# 19:30:44: Waiting for spectra function. Split 1 Analyze 0.
# 19:31:15: Waiting for spectra function. Split 2 Analyze 1.
# 19:31:46: Waiting for spectra function. Split 3 Analyze 1.
# 19:32:18: Waiting for spectra function. Split 4 Analyze 3.
# 19:32:49: Waiting for spectra function. Split 5 Analyze 4.
# 19:33:20: Waiting for spectra function. Split 6 Analyze 5.
# 19:33:51: Waiting for spectra function. Split 6 Analyze 6.
# 19:34:23: Waiting for spectra function. Split 7 Analyze 7.
# 19:34:54: Waiting for spectra function. Split 10 Analyze 8.
# 19:35:25: Waiting for spectra function. Split 11 Analyze 10.
# 19:35:57: Found spectra function
# 19:35:57: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:36:29: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:37:00: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:37:31: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:38:03: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:38:34: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:39:05: Found percolator.decoy functions
# 19:39:06: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531870466386
# Billed Duration 253800 milliseconds
# Max Memory Used 1745
# Cost 0.012428586
#
# analyze_spectra
# Min Timestamp 1531870269211
# Max Timestamp 1531870510897
# Min Memory 1706
# Max Memory 1968
# Max Billed Duration 36300 milliseconds
# Total Billed Duration 282500 milliseconds
# Cost 0.013834025
#
# Combine Spectra
# Timestamp 1531870520298
# Billed Duration 13800 milliseconds
# Max Memory Used 256
# Cost 5.7546e-05
#
# Percolator Spectra
# Timestamp 1531870744818
# Billed Duration 210900 milliseconds
# Max Memory Used 2103
# Cost 0.010327773
#
# END RESULTS
# Total Cost 0.036647929999999995
# Total Runtime 594.6574407100677 seconds
# Total Billed Duration 761.0 seconds
# Total Memory Used 23253 MB
# key percolator.target.peptides.txt qvalues 25426
# key percolator.target.psms.txt qvalues 36552
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531870770.349893-1-0-1-1.mzML last modified 1531870774000.0
# 19:40:41: Waiting for spectra function. Split 0 Analyze 0.
# 19:41:13: Waiting for spectra function. Split 1 Analyze 0.
# 19:41:44: Waiting for spectra function. Split 2 Analyze 1.
# 19:42:16: Waiting for spectra function. Split 3 Analyze 2.
# 19:42:47: Waiting for spectra function. Split 4 Analyze 3.
# 19:43:19: Waiting for spectra function. Split 5 Analyze 4.
# 19:43:50: Waiting for spectra function. Split 6 Analyze 5.
# 19:44:21: Waiting for spectra function. Split 7 Analyze 6.
# 19:44:52: Waiting for spectra function. Split 9 Analyze 8.
# 19:45:24: Waiting for spectra function. Split 10 Analyze 8.
# 19:45:55: Waiting for spectra function. Split 11 Analyze 10.
# 19:46:26: Found spectra function
# 19:46:27: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:46:58: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:47:29: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:48:01: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:48:32: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:49:03: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:49:35: Found percolator.decoy functions
# 19:49:35: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531871084723
# Billed Duration 243100 milliseconds
# Max Memory Used 1745
# Cost 0.011904607
#
# analyze_spectra
# Min Timestamp 1531870896053
# Max Timestamp 1531871144636
# Min Memory 1155
# Max Memory 1973
# Max Billed Duration 41500 milliseconds
# Total Billed Duration 284900 milliseconds
# Cost 0.013951553
#
# Combine Spectra
# Timestamp 1531871144940
# Billed Duration 13700 milliseconds
# Max Memory Used 256
# Cost 5.7129e-05
#
# Percolator Spectra
# Timestamp 1531871370260
# Billed Duration 211800 milliseconds
# Max Memory Used 2105
# Cost 0.010371846
#
# END RESULTS
# Total Cost 0.036285134999999996
# Total Runtime 581.1606536865235 seconds
# Total Billed Duration 753.5 seconds
# Total Memory Used 22650 MB
# key percolator.target.peptides.txt qvalues 25350
# key percolator.target.psms.txt qvalues 36645
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1531871399.469014-1-0-1-1.mzML last modified 1531871404000.0
# 19:51:21: Waiting for spectra function. Split 0 Analyze 0.
# 19:51:52: Waiting for spectra function. Split 1 Analyze 0.
# 19:52:23: Waiting for spectra function. Split 2 Analyze 1.
# 19:52:54: Waiting for spectra function. Split 3 Analyze 2.
# 19:53:25: Waiting for spectra function. Split 4 Analyze 3.
# 19:53:57: Waiting for spectra function. Split 5 Analyze 4.
# 19:54:28: Waiting for spectra function. Split 6 Analyze 5.
# 19:54:59: Waiting for spectra function. Split 7 Analyze 6.
# 19:55:31: Waiting for spectra function. Split 9 Analyze 8.
# 19:56:02: Waiting for spectra function. Split 11 Analyze 9.
# 19:56:33: Found spectra function
# 19:56:34: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:57:05: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:57:36: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:58:07: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:58:39: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:59:10: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 19:59:41: Waiting for percolator.decoy functions. Split 11 Analyze 10.
# 20:00:12: Found percolator.decoy functions
# 20:00:13: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531871718556
# Billed Duration 237700 milliseconds
# Max Memory Used 1745
# Cost 0.011640169
#
# analyze_spectra
# Min Timestamp 1531871532231
# Max Timestamp 1531871770011
# Min Memory 640
# Max Memory 1973
# Max Billed Duration 35700 milliseconds
# Total Billed Duration 261200 milliseconds
# Cost 0.012790964
#
# Combine Spectra
# Timestamp 1531871770238
# Billed Duration 13300 milliseconds
# Max Memory Used 256
# Cost 5.5460999999999996e-05
#
# Percolator Spectra
# Timestamp 1531872007012
# Billed Duration 223600 milliseconds
# Max Memory Used 2105
# Cost 0.010949692
#
# END RESULTS
# Total Cost 0.035436286
# Total Runtime 591.438473033905 seconds
# Total Billed Duration 735.8 seconds
# Total Memory Used 21331 MB
# key percolator.target.peptides.txt qvalues 25426
# key percolator.target.psms.txt qvalues 36552
# Deleted 1 input objects
# Deleted 11 merge objects
# Deleted 10 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 74.46867082118987 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.011976103200000001
# Total Runtime 244.56 seconds
# Total Billed Duration 244.56 seconds
# Total Memory Used 1744.3 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.013765467
# Total Runtime 38.91 seconds
# Total Billed Duration 281.1 seconds
# Total Memory Used 16747.8 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 5.95893e-05
# Total Runtime 14.29 seconds
# Total Billed Duration 14.29 seconds
# Total Memory Used 252.5 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0104222851
# Total Runtime 212.83 seconds
# Total Billed Duration 212.83 seconds
# Total Memory Used 2100.4 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.036223444599999995
# Total Runtime 585.0586708211899 seconds
# Total Billed Duration 752.78 seconds
# Total Memory Used 20845.0 MB

# %%
import constants
import util
import sort
import benchmark
import importlib
import subprocess
importlib.reload(constants)
importlib.reload(util)
importlib.reload(sort)
importlib.reload(benchmark)

print("Test large COON file. No sort.")
subprocess.call("python3 test.py", shell=True)

batch_size = 16000
params = {
  "input_name": "ASH_20170314_HELA_90MIN_20170320042659.mzML",
  "iterations": 10,
  "region": "us-west-2",
  "sort": "no",
  "lambda": False,
  "timeout": 300,
  "check_output": True,
  "ec2": {
    "ami": "ami-fd9bc885",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.large",
    "wait_for_tests": False,
    "use_ami": True
  },
  "split_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": batch_size,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 3008,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 0,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

benchmark.run(params)
# Out:
# Test large COON file. No sort.
# Current Git commit f3c1e49 lambda: Allow splits in analysis function
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532027564.653816-1-0-1-1.mzML last modified 1532027569000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9543110357411702
# Total Runtime 790.166081905365 seconds
# Total Billed Duration 665.6430509090424 seconds
# Total Memory Used 0 MB
# key spectra-1532027564.653816-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532028382.889798-1-0-1-1.mzML last modified 1532028387000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9303748835118612
# Total Runtime 739.6890189647675 seconds
# Total Billed Duration 665.6619591712952 seconds
# Total Memory Used 0 MB
# key spectra-1532028382.889798-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532029136.621830-1-0-1-1.mzML last modified 1532029141000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9483676103210448
# Total Runtime 731.6156415939331 seconds
# Total Billed Duration 661.7540435791016 seconds
# Total Memory Used 0 MB
# key spectra-1532029136.621830-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532029882.091228-1-0-1-1.mzML last modified 1532029886000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9391221917088827
# Total Runtime 749.7043654918671 seconds
# Total Billed Duration 671.2005302906036 seconds
# Total Memory Used 0 MB
# key spectra-1532029882.091228-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532030648.242009-1-0-1-1.mzML last modified 1532030652000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9406206743876139
# Total Runtime 828.8445649147034 seconds
# Total Billed Duration 672.6273882389069 seconds
# Total Memory Used 0 MB
# key spectra-1532030648.242009-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532031492.073243-1-0-1-1.mzML last modified 1532031496000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 1.0227487878163657
# Total Runtime 797.1558616161346 seconds
# Total Billed Duration 724.93590092659 seconds
# Total Memory Used 0 MB
# key spectra-1532031492.073243-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532032308.695956-1-0-1-1.mzML last modified 1532032313000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9315468735504151
# Total Runtime 724.596596956253 seconds
# Total Billed Duration 650.9185605049133 seconds
# Total Memory Used 0 MB
# key spectra-1532032308.695956-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532033048.437630-1-0-1-1.mzML last modified 1532033052000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9324460195032754
# Total Runtime 738.2856526374817 seconds
# Total Billed Duration 651.7051918506622 seconds
# Total Memory Used 0 MB
# key spectra-1532033048.437630-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532033811.948318-1-0-1-1.mzML last modified 1532033816000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.933880216916402
# Total Runtime 723.0511782169342 seconds
# Total Billed Duration 652.1841714382172 seconds
# Total Memory Used 0 MB
# key spectra-1532033811.948318-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to S3
# spectra-1532034548.584166-1-0-1-1.mzML last modified 1532034553000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 instance.
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.9215565388997394
# Total Runtime 742.1657934188843 seconds
# Total Billed Duration 644.4939434528351 seconds
# Total Memory Used 0 MB
# key spectra-1532034548.584166-1-1-1.txt num_lines 880332
# key percolator.target.peptides.txt qvalues 35861
# key percolator.target.psms.txt qvalues 57857
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 90.41500153541566 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE CREATE RESULTS
# Total Cost 0.0
# Total Runtime 17.03238365650177 seconds
# Total Billed Duration 17.03238365650177 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE INITIATE RESULTS
# Total Cost 0.011795209849039713
# Total Runtime 7.626213264465332 seconds
# Total Billed Duration 7.626213264465332 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SETUP RESULTS
# Total Cost 0.0004896901003519693
# Total Runtime 0.3166099786758423 seconds
# Total Billed Duration 0.3166099786758423 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE DOWNLOAD RESULTS
# Total Cost 0.041604116408030196
# Total Runtime 26.899213194847107 seconds
# Total Billed Duration 26.899213194847107 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TIDE RESULTS
# Total Cost 0.3756782232755025
# Total Runtime 242.89540297985076 seconds
# Total Billed Duration 242.89540297985076 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.5050759115676879
# Total Runtime 326.5577014446259 seconds
# Total Billed Duration 326.5577014446259 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE UPLOAD RESULTS
# Total Cost 0.010854332035064695
# Total Runtime 7.017887091636657 seconds
# Total Billed Duration 7.017887091636657 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TERMINATE RESULTS
# Total Cost 0.0
# Total Runtime 37.7670624256134 seconds
# Total Billed Duration 37.7670624256134 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.9454974832356771
# Total Runtime 756.5274755716324 seconds
# Total Billed Duration 666.1124740362168 seconds
# Total Memory Used 0.0 MB

# %%
from subprocess import Popen, PIPE
import subprocess

print("Hello")
p = Popen(["ls", "~/.ssh"], stdout=PIPE, stderr=PIPE)
output, error = p.communicate()
print("goodbye")
print("\n".join(str(output).split("\\n")))
print("\n".join(str(error).split("\\n")))


#subprocess.call("git add benchmark.py", shell=True)
#subprocess.call("git commit -m 'benchmark: Add memory ranges'", shell=True)
# Out:
# Hello
# goodbye
# b''
# b"ls: cannot access '~/.ssh': No such file or directory
# "
