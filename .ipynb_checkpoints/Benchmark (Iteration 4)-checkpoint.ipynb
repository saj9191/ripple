# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Test benchmark checks for EC2")

params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Test benchmark checks for EC2
# Current Git commit 83d34b3 benchmark: Add Tide output check
#
# Iteration 0
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.19386412605285644
# Total Runtime 376.274206161499 seconds
# Total Billed Duration 376.274206161499 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 1
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.24304185937245684
# Total Runtime 378.26246452331543 seconds
# Total Billed Duration 378.26246452331543 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 2
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22107395189921059
# Total Runtime 349.9500324726105 seconds
# Total Billed Duration 349.9500324726105 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 3
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22120352396647133
# Total Runtime 349.9707396030426 seconds
# Total Billed Duration 349.9707396030426 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 4
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.21756193556467687
# Total Runtime 345.61405396461487 seconds
# Total Billed Duration 345.61405396461487 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 5
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22153059075673417
# Total Runtime 350.5394985675812 seconds
# Total Billed Duration 350.5394985675812 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 6
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22129027483622232
# Total Runtime 350.5265791416168 seconds
# Total Billed Duration 350.5265791416168 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 7
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.22060634482065833
# Total Runtime 334.29519844055176 seconds
# Total Billed Duration 334.29519844055176 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 8
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.2198169669977824
# Total Runtime 348.2685503959656 seconds
# Total Billed Duration 348.2685503959656 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# Iteration 9
# Waiting for instance to initiate
# Wait for status checks
# Running Tide
# Running Percolator
# Uploading files to s3
# END RESULTS
# Total Cost 0.2458230787086487
# Total Runtime 381.8501477241516 seconds
# Total Billed Duration 381.8501477241516 seconds
# Total Memory Used 0 MB
# Deleted 0 input objects
# Deleted 0 split objects
# Deleted 5 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE CREATE RESULTS
# Total Cost 0.0
# Total Runtime 18.668372106552123 seconds
# Total Billed Duration 18.668372106552123 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE LOAD RESULTS
# Total Cost 0.15305148112424213
# Total Runtime 197.91139800548552 seconds
# Total Billed Duration 197.91139800548552 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TIDE RESULTS
# Total Cost 0.027192512879689535
# Total Runtime 35.162732172012326 seconds
# Total Billed Duration 35.162732172012326 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.039528112604777024
# Total Runtime 51.11393871307373 seconds
# Total Billed Duration 51.11393871307373 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE UPLOAD RESULTS
# Total Cost 0.0028091586888631184
# Total Runtime 3.6325327873229982 seconds
# Total Billed Duration 3.6325327873229982 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TERMINATE RESULTS
# Total Cost 0.0
# Total Runtime 50.06617331504822 seconds
# Total Billed Duration 50.06617331504822 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.22258126529757183
# Total Runtime 356.55514709949495 seconds
# Total Billed Duration 356.55514709949495 seconds
# Total Memory Used 0.0 MB

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Test benchmark checks for Lambda")

params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "region": "us-west-2",
  "sort": false,
  "lambda": true,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectraResults",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Test benchmark checks for Lambda
# Current Git commit 0b9de5b benchmark: Change check to be a percentage of expected value
#
# Iteration 0
# sorted_20170403_HelaQC_01.ms2 last modified 1531097308000.0
# 20:48:30: Waiting for tide-search function...
# 20:49:01: Waiting for tide-search function...
# 20:49:31: Found tide-search function
# 20:49:32: Waiting for percolator.decoy functions...
# 20:50:02: Found percolator.decoy functions
# 20:50:03: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097316352
# Billed Duration 5200 milliseconds
# Max Memory Used 470
# Cost 8.6684e-05
#
# Analyze Spectra
# Min Timestamp 1531097328906
# Max Timestamp 1531097342868
# Max Billed Duration 29000 milliseconds
# Total Billed Duration 140000 milliseconds
# Cost 0.0023338
#
# Combine Spectra
# Timestamp 1531097343277
# Billed Duration 3200 milliseconds
# Max Memory Used 95
# Cost 1.3344e-05
#
# Percolator Spectra
# Timestamp 1531097395873
# Billed Duration 48900 milliseconds
# Max Memory Used 532
# Cost 0.0023946329999999997
#
# END RESULTS
# Total Cost 0.004828461
# Total Runtime 89.47727065086364 seconds
# Total Billed Duration 197.3 seconds
# Total Memory Used 5134 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 1
# sorted_20170403_HelaQC_01.ms2 last modified 1531097424000.0
# 20:50:27: Waiting for tide-search function...
# 20:50:57: Waiting for tide-search function...
# 20:51:28: Found tide-search function
# 20:51:28: Waiting for percolator.decoy functions...
# 20:51:59: Found percolator.decoy functions
# 20:51:59: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097431133
# Billed Duration 4500 milliseconds
# Max Memory Used 510
# Cost 7.5015e-05
#
# Analyze Spectra
# Min Timestamp 1531097443984
# Max Timestamp 1531097457552
# Max Billed Duration 28100 milliseconds
# Total Billed Duration 139100 milliseconds
# Cost 0.002318797
#
# Combine Spectra
# Timestamp 1531097457820
# Billed Duration 3300 milliseconds
# Max Memory Used 101
# Cost 1.3761e-05
#
# Percolator Spectra
# Timestamp 1531097509573
# Billed Duration 48700 milliseconds
# Max Memory Used 538
# Cost 0.002384839
#
# END RESULTS
# Total Cost 0.004792412
# Total Runtime 87.56788835525512 seconds
# Total Billed Duration 195.6 seconds
# Total Memory Used 5352 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 2
# sorted_20170403_HelaQC_01.ms2 last modified 1531097542000.0
# 20:52:24: Waiting for tide-search function...
# 20:52:54: Waiting for tide-search function...
# 20:53:25: Found tide-search function
# 20:53:25: Waiting for percolator.decoy functions...
# 20:53:56: Found percolator.decoy functions
# 20:53:56: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097547549
# Billed Duration 3600 milliseconds
# Max Memory Used 558
# Cost 6.0012e-05
#
# Analyze Spectra
# Min Timestamp 1531097559540
# Max Timestamp 1531097574729
# Max Billed Duration 28300 milliseconds
# Total Billed Duration 148200 milliseconds
# Cost 0.002470494
#
# Combine Spectra
# Timestamp 1531097574773
# Billed Duration 3600 milliseconds
# Max Memory Used 101
# Cost 1.5012e-05
#
# Percolator Spectra
# Timestamp 1531097627150
# Billed Duration 48800 milliseconds
# Max Memory Used 533
# Cost 0.002389736
#
# END RESULTS
# Total Cost 0.004935254
# Total Runtime 87.5199809551239 seconds
# Total Billed Duration 204.2 seconds
# Total Memory Used 5431 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 3
# sorted_20170403_HelaQC_01.ms2 last modified 1531097660000.0
# 20:54:22: Waiting for tide-search function...
# 20:54:53: Waiting for tide-search function...
# 20:55:23: Found tide-search function
# 20:55:24: Waiting for percolator.decoy functions...
# 20:55:55: Found percolator.decoy functions
# 20:55:56: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097666239
# Billed Duration 3800 milliseconds
# Max Memory Used 559
# Cost 6.3346e-05
#
# Analyze Spectra
# Min Timestamp 1531097678007
# Max Timestamp 1531097699486
# Max Billed Duration 34600 milliseconds
# Total Billed Duration 148500 milliseconds
# Cost 0.0024754950000000003
#
# Combine Spectra
# Timestamp 1531097699733
# Billed Duration 4100 milliseconds
# Max Memory Used 104
# Cost 1.7097e-05
#
# Percolator Spectra
# Timestamp 1531097751165
# Billed Duration 47500 milliseconds
# Max Memory Used 539
# Cost 0.002326075
#
# END RESULTS
# Total Cost 0.004882013000000001
# Total Runtime 93.56205654144287 seconds
# Total Billed Duration 203.9 seconds
# Total Memory Used 5455 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 4
# sorted_20170403_HelaQC_01.ms2 last modified 1531097777000.0
# 20:56:20: Waiting for tide-search function...
# 20:56:50: Waiting for tide-search function...
# 20:57:21: Found tide-search function
# 20:57:21: Waiting for percolator.decoy functions...
# 20:57:52: Found percolator.decoy functions
# 20:57:52: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097783605
# Billed Duration 3800 milliseconds
# Max Memory Used 559
# Cost 6.3346e-05
#
# Analyze Spectra
# Min Timestamp 1531097795643
# Max Timestamp 1531097814509
# Max Billed Duration 31900 milliseconds
# Total Billed Duration 143500 milliseconds
# Cost 0.002392145
#
# Combine Spectra
# Timestamp 1531097814744
# Billed Duration 3300 milliseconds
# Max Memory Used 105
# Cost 1.3761e-05
#
# Percolator Spectra
# Timestamp 1531097865276
# Billed Duration 47400 milliseconds
# Max Memory Used 540
# Cost 0.002321178
#
# END RESULTS
# Total Cost 0.00479043
# Total Runtime 89.86717667579651 seconds
# Total Billed Duration 198.0 seconds
# Total Memory Used 5467 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 5
# sorted_20170403_HelaQC_01.ms2 last modified 1531097893000.0
# 20:58:15: Waiting for tide-search function...
# 20:58:46: Waiting for tide-search function...
# 20:59:16: Found tide-search function
# 20:59:17: Waiting for percolator.decoy functions...
# 20:59:47: Found percolator.decoy functions
# 20:59:48: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531097899145
# Billed Duration 3700 milliseconds
# Max Memory Used 568
# Cost 6.1679e-05
#
# Analyze Spectra
# Min Timestamp 1531097910748
# Max Timestamp 1531097929224
# Max Billed Duration 31600 milliseconds
# Total Billed Duration 141200 milliseconds
# Cost 0.002353804
#
# Combine Spectra
# Timestamp 1531097929437
# Billed Duration 3100 milliseconds
# Max Memory Used 110
# Cost 1.2927e-05
#
# Percolator Spectra
# Timestamp 1531097980709
# Billed Duration 48300 milliseconds
# Max Memory Used 541
# Cost 0.002365251
#
# END RESULTS
# Total Cost 0.004793660999999999
# Total Runtime 89.86316604614258 seconds
# Total Billed Duration 196.3 seconds
# Total Memory Used 5504 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 6
# sorted_20170403_HelaQC_01.ms2 last modified 1531098011000.0
# 21:00:13: Waiting for tide-search function...
# 21:00:44: Waiting for tide-search function...
# 21:01:14: Found tide-search function
# 21:01:15: Waiting for percolator.decoy functions...
# 21:01:45: Found percolator.decoy functions
# 21:01:46: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531098017001
# Billed Duration 3900 milliseconds
# Max Memory Used 568
# Cost 6.501300000000001e-05
#
# Analyze Spectra
# Min Timestamp 1531098028951
# Max Timestamp 1531098045705
# Max Billed Duration 30300 milliseconds
# Total Billed Duration 137900 milliseconds
# Cost 0.002298793
#
# Combine Spectra
# Timestamp 1531098045968
# Billed Duration 3200 milliseconds
# Max Memory Used 112
# Cost 1.3344e-05
#
# Percolator Spectra
# Timestamp 1531098097938
# Billed Duration 48900 milliseconds
# Max Memory Used 543
# Cost 0.0023946329999999997
#
# END RESULTS
# Total Cost 0.004771783
# Total Runtime 89.41883115768432 seconds
# Total Billed Duration 193.9 seconds
# Total Memory Used 5520 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 7
# sorted_20170403_HelaQC_01.ms2 last modified 1531098127000.0
# 21:02:09: Waiting for tide-search function...
# 21:02:40: Waiting for tide-search function...
# 21:03:10: Found tide-search function
# 21:03:11: Waiting for percolator.decoy functions...
# 21:03:41: Found percolator.decoy functions
# 21:03:42: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531098133263
# Billed Duration 4100 milliseconds
# Max Memory Used 568
# Cost 6.8347e-05
# Analyze Spectra
# Min Timestamp 1531098144947
# Max Timestamp 1531098162088
# Max Billed Duration 30400 milliseconds
# Total Billed Duration 143200 milliseconds
# Cost 0.0023871440000000003
#
# Combine Spectra
# Timestamp 1531098162251
# Billed Duration 3400 milliseconds
# Max Memory Used 112
# Cost 1.4177999999999999e-05
#
# Percolator Spectra
# Timestamp 1531098212897
# Billed Duration 47400 milliseconds
# Max Memory Used 543
# Cost 0.002321178
#
# END RESULTS
# Total Cost 0.004790847000000001
# Total Runtime 88.37658672332763 seconds
# Total Billed Duration 198.1 seconds
# Total Memory Used 5525 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 8
# sorted_20170403_HelaQC_01.ms2 last modified 1531098244000.0
# 21:04:06: Waiting for tide-search function...
# 21:04:36: Waiting for tide-search function...
# 21:05:07: Found tide-search function
# 21:05:07: Waiting for percolator.decoy functions...
# 21:05:38: Found percolator.decoy functions
# 21:05:38: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531098249084
# Billed Duration 3300 milliseconds
# Max Memory Used 568
# Cost 5.5011000000000006e-05
#
# Analyze Spectra
# Min Timestamp 1531098264167
# Max Timestamp 1531098281926
# Max Billed Duration 33900 milliseconds
# Total Billed Duration 139600 milliseconds
# Cost 0.002327132
#
# Combine Spectra
# Timestamp 1531098282214
# Billed Duration 3200 milliseconds
# Max Memory Used 113
# Cost 1.3344e-05
#
# Percolator Spectra
# Timestamp 1531098333618
# Billed Duration 48500 milliseconds
# Max Memory Used 542
# Cost 0.002375045
#
# END RESULTS
# Total Cost 0.004770532000000001
# Total Runtime 91.90987720489503 seconds
# Total Billed Duration 194.6 seconds
# Total Memory Used 5585 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# Iteration 9
# sorted_20170403_HelaQC_01.ms2 last modified 1531098359000.0
# 21:06:02: Waiting for tide-search function...
# 21:06:32: Waiting for tide-search function...
# 21:07:03: Found tide-search function
# 21:07:03: Waiting for percolator.decoy functions...
# 21:07:34: Found percolator.decoy functions
# 21:07:34: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531098365893
# Billed Duration 4300 milliseconds
# Max Memory Used 568
# Cost 7.168100000000001e-05
#
# Analyze Spectra
# Min Timestamp 1531098378249
# Max Timestamp 1531098394786
# Max Billed Duration 30900 milliseconds
# Total Billed Duration 142600 milliseconds
# Cost 0.002377142
#
# Combine Spectra
# Timestamp 1531098395097
# Billed Duration 3900 milliseconds
# Max Memory Used 113
# Cost 1.6263e-05
#
# Percolator Spectra
# Timestamp 1531098447214
# Billed Duration 48400 milliseconds
# Max Memory Used 542
# Cost 0.002370148
#
# END RESULTS
# Total Cost 0.004835234
# Total Runtime 90.57280683517456 seconds
# Total Billed Duration 199.2 seconds
# Total Memory Used 5588 MB
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 11 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 3.1835641145706175 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 6.701339999999999e-05
# Total Runtime 4.02 seconds
# Total Billed Duration 4.02 seconds
# Total Memory Used 549.6 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.0023734745999999998
# Total Runtime 30.9 seconds
# Total Billed Duration 142.38 seconds
# Total Memory Used 4260.6 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 1.43031e-05
# Total Runtime 3.43 seconds
# Total Billed Duration 3.43 seconds
# Total Memory Used 106.6 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0023642715999999996
# Total Runtime 48.28 seconds
# Total Billed Duration 48.28 seconds
# Total Memory Used 539.3 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.0048190627
# Total Runtime 89.81356411457062 seconds
# Total Billed Duration 198.11 seconds
# Total Memory Used 5456.1 MB
