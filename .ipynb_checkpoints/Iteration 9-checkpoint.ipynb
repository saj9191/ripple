# %%
import constants
import util
import sort
import benchmark
import json

print("Test first EC2 coordinator attempt")

params = json.loads(open("json/default.json").read())
benchmark.run(params)
# Out:
# Test first EC2 coordinator attempt
# Current Git commit a924746 parameters: Two sets of parameters
#
# SplitSpectra ['split_spectra.py', 'split_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'split.py', 'util.py']
# SortSpectra ['sort_spectra.py', 'sort_spectra.json']
# MergeSpectra ['merge_spectra.py', 'merge_spectra.json']
# AnalyzeSpectra ['analyze_spectra.py', 'analyze_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'util.py']
# CombineSpectra ['combine_spectra_results.py', 'combine_spectra_results.json', 'constants.py', 'util.py']
# Percolator ['percolator.py', 'percolator.json', 'constants.py', 'util.py']
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532127790.891182-1-0-1-1.mzML last modified 1532127795000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Uploading files to s3
# END RESULTS
# ...

# %%
print("Test Lambda attempt")
params = json.loads(open("json/default.json").read())
params["model"] = "lambda"
benchmark.run(params)
# Out:
# Test Lambda attempt
# Current Git commit a924746 parameters: Two sets of parameters
#
# SplitSpectra ['split_spectra.py', 'split_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'split.py', 'util.py']
# SortSpectra ['sort_spectra.py', 'sort_spectra.json']
# MergeSpectra ['merge_spectra.py', 'merge_spectra.json']
# AnalyzeSpectra ['analyze_spectra.py', 'analyze_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'util.py']
# CombineSpectra ['combine_spectra_results.py', 'combine_spectra_results.json', 'constants.py', 'util.py']
# Percolator ['percolator.py', 'percolator.json', 'constants.py', 'util.py']
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532142689.501399-1-0-1-1.mzML last modified 1532142693000.0
# 23:12:13: Waiting for spectra function. Analyze 0.
# 23:12:44: Waiting for spectra function. Analyze 5.
# 23:13:14: Waiting for spectra function. Analyze 177.
# ...

# %%
import constants
import util
import benchmark
import json
import importlib

importlib.reload(constants)
importlib.reload(util)
importlib.reload(benchmark)

print("Test Coordinator with Analyze logic")
params = json.loads(open("json/default.json").read())
params["model"] = "coordinator"
benchmark.run(params)
# Out:
# Test Coordinator with Analyze logic
# Current Git commit e3a0530 Coordinator: Need mult client variables
#
# SplitSpectra ['split_spectra.py', 'split_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'split.py', 'util.py']
# SortSpectra ['sort_spectra.py', 'sort_spectra.json']
# MergeSpectra ['merge_spectra.py', 'merge_spectra.json']
# AnalyzeSpectra ['analyze_spectra.py', 'analyze_spectra.json', 'constants.py', 'header.mzML', 'spectra.py', 'util.py']
# CombineSpectra ['combine_spectra_results.py', 'combine_spectra_results.json', 'constants.py', 'util.py']
# Percolator ['percolator.py', 'percolator.json', 'constants.py', 'util.py']
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532227599.810911-1-0-1-1.mzML last modified 1532227604000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# ...

# %%
import constants
import util
import benchmark
import json
import importlib

importlib.reload(constants)
importlib.reload(util)
importlib.reload(benchmark)

print("Test Coordinator with duration stats for each part of coordinator")
params = json.loads(open("json/default.json").read())
params["model"] = "coordinator"
benchmark.run(params)
# Out:
# Test Coordinator with duration stats for each part of coordinator
# Current Git commit 7ac5923 Fix typo
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532314535.045954-1-0-1-1.mzML last modified 1532314539000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532314737144
# Max Timestamp 1532314803211
# Min Memory 707
# Max Memory 799
# Max Billed Duration 85700 milliseconds
# Total Billed Duration 6555100 milliseconds
# Cost 0.109273517
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.6922951429702047
# Total Runtime 946.3566417217255 seconds
# Total Billed Duration 7371.442469692231 seconds
# Total Memory Used 141204 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 1
# ...

# %%
import constants
import util
import benchmark
import json
import importlib

importlib.reload(constants)
importlib.reload(util)
importlib.reload(benchmark)

print("Test Coordinator with duration stats for each part of coordinator")
params = json.loads(open("json/default.json").read())
params["model"] = "coordinator"
benchmark.run(params)
# Out:
# Test Coordinator with duration stats for each part of coordinator
# Current Git commit 7ac5923 Fix typo
#
#
# Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532348820.167182-1-0-1-1.mzML last modified 1532348824000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532349933601
# Max Timestamp 1532350070018
# Min Memory 704
# Max Memory 804
# Max Billed Duration 164100 milliseconds
# Total Billed Duration 6719500 milliseconds
# Cost 0.11201406500000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7673456705234272
# Total Runtime 1137.3845120429992 seconds
# Total Billed Duration 7644.715596437454 seconds
# Total Memory Used 142412 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 2
# ...

# %% [raw]
# # Iteration 0
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532350909.372028-1-0-1-1.mzML last modified 1532350913000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532351126196
# Max Timestamp 1532351169672
# Min Memory 706
# Max Memory 803
# Max Billed Duration 59300 milliseconds
# Total Billed Duration 6534000 milliseconds
# Cost 0.10892178000000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.6594255965092468
# Total Runtime 916.4797995567321 seconds
# Total Billed Duration 7338.8539934158325 seconds
# Total Memory Used 141219 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 1
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532351819.287445-1-0-1-1.mzML last modified 1532351823000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532352061417
# Max Timestamp 1532352110576
# Min Memory 705
# Max Memory 799
# Max Billed Duration 67400 milliseconds
# Total Billed Duration 6456000 milliseconds
# Cost 0.10762152000000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.6749350486394755
# Total Runtime 951.3046583175659 seconds
# Total Billed Duration 7267.181167602539 seconds
# Total Memory Used 142178 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 2
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532352803.596692-1-0-1-1.mzML last modified 1532352807000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532353021679
# Max Timestamp 1532353125533
# Min Memory 705
# Max Memory 799
# Max Billed Duration 123400 milliseconds
# Total Billed Duration 6660700 milliseconds
# Cost 0.11103386900000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7256109702560527
# Total Runtime 1071.9121996402741 seconds
# Total Billed Duration 7563.938389253616 seconds
# Total Memory Used 142604 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 3
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532353836.707618-1-0-1-1.mzML last modified 1532353841000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532354053824
# Max Timestamp 1532354135889
# Min Memory 704
# Max Memory 800
# Max Billed Duration 99600 milliseconds
# Total Billed Duration 6568500 milliseconds
# Cost 0.10949689500000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7042268386060587
# Total Runtime 1022.8119781970978 seconds
# Total Billed Duration 7445.960649490356 seconds
# Total Memory Used 142186 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 4
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532354843.075731-1-0-1-1.mzML last modified 1532354847000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532355085006
# Max Timestamp 1532355154837
# Min Memory 703
# Max Memory 800
# Max Billed Duration 94800 milliseconds
# Total Billed Duration 6585900 milliseconds
# Cost 0.109786953
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.6873131137805887
# Total Runtime 993.898420381546 seconds
# Total Billed Duration 7418.798075103759 seconds
# Total Memory Used 142225 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 5
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532355851.776892-1-0-1-1.mzML last modified 1532355856000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532356072850
# Max Timestamp 1532356126358
# Min Memory 705
# Max Memory 799
# Max Billed Duration 77200 milliseconds
# Total Billed Duration 6644200 milliseconds
# Cost 0.11075881400000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7087475044271444
# Total Runtime 986.6082942008973 seconds
# Total Billed Duration 7495.007545900345 seconds
# Total Memory Used 142663 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 6
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532356824.882612-1-0-1-1.mzML last modified 1532356829000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532357064312
# Max Timestamp 1532357240511
# Min Memory 704
# Max Memory 799
# Max Billed Duration 199200 milliseconds
# Total Billed Duration 6826000 milliseconds
# Cost 0.11378942
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7958078992836508
# Total Runtime 1212.036902141571 seconds
# Total Billed Duration 7785.5932874679565 seconds
# Total Memory Used 142478 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 7
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532357985.423393-1-0-1-1.mzML last modified 1532357989000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532358221951
# Max Timestamp 1532358296626
# Min Memory 705
# Max Memory 800
# Max Billed Duration 98800 milliseconds
# Total Billed Duration 6981600 milliseconds
# Cost 0.11638327200000001
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7078337016620686
# Total Runtime 1001.2089713096618 seconds
# Total Billed Duration 7824.945623016358 seconds
# Total Memory Used 142251 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 8
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532359022.528611-1-0-1-1.mzML last modified 1532359026000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
# analyze_spectra
# Min Timestamp 1532359243581
# Max Timestamp 1532359418435
# Min Memory 705
# Max Memory 799
# Max Billed Duration 196100 milliseconds
# Total Billed Duration 6664300 milliseconds
# Cost 0.111093881
#
# Uploading files to s3
# END RESULTS
# Total Cost 0.7659335494201557
# Total Runtime 1189.7885554790496 seconds
# Total Billed Duration 7603.866070079804 seconds
# Total Memory Used 142015 MB
# Deleted 1 input objects
# Deleted 182 analyze objects
# --------------------------
#
# Iteration 9
# Uploading ASH_20170314_HELA_90MIN_20170320042659.mzML to s3://shjoyner-human-input-spectra
# spectra-1532360127.523615-1-0-1-1.mzML last modified 1532360131000.0
# Waiting for instance to initiate.
# Connecting to EC2 instance.
# Setting up EC2 Coordinator instance.
# Running coordinator
