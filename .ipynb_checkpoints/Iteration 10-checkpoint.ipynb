# %%
import subprocess

print("Lambda: Batch size 1000")
print(subprocess.check_output("cat maccoss-lambda.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Lambda: Batch size 1000
# ...

# %%
import subprocess

print("Lambda: Batch size 2000")
print(subprocess.check_output("cat maccoss-lambda.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Lambda: Batch size 2000
# ...

# %%
import subprocess

print("Coordinator: Batch size 1000")
print(subprocess.check_output("cat default-coordinator.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 1000
# ...

# %%
import subprocess

print("Coordinator: Batch size 2000")
print(subprocess.check_output("cat default-coordinator.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 2000
# ...

# %%
import subprocess

print("EC2")
print(subprocess.check_output("cat maccoss-lambda.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# EC2
# ...

# %%
import subprocess

print("Lambda: Batch size 4000")
print(subprocess.check_output("cat maccoss-lambda.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 4000
# ...

# %%
import subprocess

print("Coordinator: Batch size 4000")
print(subprocess.check_output("cat maccoss-coordinator.txt | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 4000
# ...

# %%
import subprocess

print("Coordinator: Batch size 2000. West coast.")
print(subprocess.check_output("cat maccoss-coordinator.txt | grep -v INFO | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 2000. West coast.
# ...

# %%
import subprocess

print("Coordinator: Batch size 1000. West coast.")
print(subprocess.check_output("cat maccoss-coordinator.txt | grep -v INFO | grep -v logGroupName", shell=True).decode("utf-8"))
# Out:
# Coordinator: Batch size 1000. West coast.
# ...

# %%
import subprocess

print("Lambda: Batch size 4000")
print(subprocess.check_output("cat maccoss-lambda.txt | grep -v logGroupName", shell=True).decode("utf-8"))
