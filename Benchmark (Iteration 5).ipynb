# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)


print("Test non-merge benchmark on Lambda for small file")

params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "lambda": true,
  "merge": false,
  "region": "us-west-2",
  "sort": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "cost": 0.0464,
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 1000,
    "chunk_size": 100000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": 1000,
    "chunk_size": 10000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

""")
benchmark.run(params)
# Out:
# Test non-merge benchmark on Lambda for small file
# Current Git commit 6f6fc52 benchmark: Add support for merge and unmerge versions
#
#
# Iteration 0
# spectra-1531263877.766484-1-1-1.ms2 last modified 1531263879000.0
# 19:04:57: Waiting for spectra function...
# 19:05:28: Found spectra function
# 19:05:28: Waiting for percolator.decoy functions...
# 19:05:59: Waiting for percolator.decoy functions...
# 19:06:29: Found percolator.decoy functions
# 19:06:30: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531263905414
# Billed Duration 7800 milliseconds
# Max Memory Used 493
# Cost 0.00013002600000000002
#
# analyze_spectra
# Min Timestamp 1531263912933
# Max Timestamp 1531263921745
# Max Billed Duration 16800 milliseconds
# Total Billed Duration 418000 milliseconds
# Cost 0.006968060000000001
#
# Combine Spectra
# Timestamp 1531263922236
# Billed Duration 5400 milliseconds
# Max Memory Used 74
# Cost 2.2518e-05
#
# Percolator Spectra
# Timestamp 1531263971004
# Billed Duration 44600 milliseconds
# Max Memory Used 519
# Cost 0.002184062
#
# END RESULTS
# Total Cost 0.009304666000000001
# Total Runtime 93.88742551803588 seconds
# Total Billed Duration 475.8 seconds
# Total Memory Used 19776 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531263877.766484-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# spectra-1531264048.533649-1-1-1.ms2 last modified 1531264049000.0
# 19:07:32: Waiting for spectra function...
# 19:08:02: Found spectra function
# 19:08:03: Waiting for percolator.decoy functions...
# 19:08:33: Waiting for percolator.decoy functions...
# 19:09:04: Found percolator.decoy functions
# 19:09:04: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264062754
# Billed Duration 11200 milliseconds
# Max Memory Used 544
# Cost 0.00018670400000000002
#
# analyze_spectra
# Min Timestamp 1531264069879
# Max Timestamp 1531264076160
# Max Billed Duration 19200 milliseconds
# Total Billed Duration 395100 milliseconds
# Cost 0.006586317
#
# Combine Spectra
# Timestamp 1531264076689
# Billed Duration 5800 milliseconds
# Max Memory Used 74
# Cost 2.4186e-05
#
# Percolator Spectra
# Timestamp 1531264134408
# Billed Duration 51900 milliseconds
# Max Memory Used 529
# Cost 0.002541543
#
# END RESULTS
# Total Cost 0.00933875
# Total Runtime 91.13479719161987 seconds
# Total Billed Duration 464.0 seconds
# Total Memory Used 20148 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264048.533649-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# spectra-1531264195.321772-1-1-1.ms2 last modified 1531264196000.0
# 19:09:59: Waiting for spectra function...
# 19:10:29: Found spectra function
# 19:10:30: Waiting for percolator.decoy functions...
# 19:11:00: Waiting for percolator.decoy functions...
# 19:11:30: Found percolator.decoy functions
# 19:11:31: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264207538
# Billed Duration 9000 milliseconds
# Max Memory Used 550
# Cost 0.00015003
#
# analyze_spectra
# Min Timestamp 1531264214953
# Max Timestamp 1531264221305
# Max Billed Duration 16900 milliseconds
# Total Billed Duration 396200 milliseconds
# Cost 0.006604654000000001
#
# Combine Spectra
# Timestamp 1531264221827
# Billed Duration 5100 milliseconds
# Max Memory Used 76
# Cost 2.1266999999999998e-05
#
# Percolator Spectra
# Timestamp 1531264277345
# Billed Duration 51200 milliseconds
# Max Memory Used 535
# Cost 0.002507264
#
# END RESULTS
# Total Cost 0.009283215000000001
# Total Runtime 85.3310260295868 seconds
# Total Billed Duration 461.5 seconds
# Total Memory Used 20290 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264195.321772-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# spectra-1531264341.717587-1-1-1.ms2 last modified 1531264343000.0
# 19:12:25: Waiting for spectra function...
# 19:12:56: Found spectra function
# 19:12:56: Waiting for percolator.decoy functions...
# 19:13:26: Waiting for percolator.decoy functions...
# 19:13:57: Found percolator.decoy functions
# 19:13:57: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264353796
# Billed Duration 7600 milliseconds
# Max Memory Used 577
# Cost 0.000126692
#
# analyze_spectra
# Min Timestamp 1531264361231
# Max Timestamp 1531264368183
# Max Billed Duration 16800 milliseconds
# Total Billed Duration 405400 milliseconds
# Cost 0.006758018
#
# Combine Spectra
# Timestamp 1531264368507
# Billed Duration 5000 milliseconds
# Max Memory Used 77
# Cost 2.085e-05
#
# Percolator Spectra
# Timestamp 1531264424650
# Billed Duration 51500 milliseconds
# Max Memory Used 537
# Cost 0.0025219549999999998
#
# END RESULTS
# Total Cost 0.009427515000000001
# Total Runtime 84.03061213493348 seconds
# Total Billed Duration 469.5 seconds
# Total Memory Used 20432 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264341.717587-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# spectra-1531264494.201926-1-1-1.ms2 last modified 1531264495000.0
# 19:14:57: Waiting for spectra function...
# 19:15:28: Found spectra function
# 19:15:28: Waiting for percolator.decoy functions...
# 19:15:59: Waiting for percolator.decoy functions...
# 19:16:29: Found percolator.decoy functions
# 19:16:30: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264506368
# Billed Duration 8700 milliseconds
# Max Memory Used 577
# Cost 0.000145029
#
# analyze_spectra
# Min Timestamp 1531264514372
# Max Timestamp 1531264521197
# Max Billed Duration 17700 milliseconds
# Total Billed Duration 405100 milliseconds
# Cost 0.006753017
#
# Combine Spectra
# Timestamp 1531264521632
# Billed Duration 4000 milliseconds
# Max Memory Used 77
# Cost 1.668e-05
#
# Percolator Spectra
# Timestamp 1531264577130
# Billed Duration 51800 milliseconds
# Max Memory Used 539
# Cost 0.002536646
#
# END RESULTS
# Total Cost 0.009451372
# Total Runtime 85.33940048217774 seconds
# Total Billed Duration 469.6 seconds
# Total Memory Used 20498 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264494.201926-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# spectra-1531264639.408143-1-1-1.ms2 last modified 1531264640000.0
# 19:17:23: Waiting for spectra function...
# 19:17:53: Found spectra function
# 19:17:54: Waiting for percolator.decoy functions...
# 19:18:24: Waiting for percolator.decoy functions...
# 19:18:55: Found percolator.decoy functions
# 19:18:55: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264650894
# Billed Duration 8100 milliseconds
# Max Memory Used 578
# Cost 0.00013502700000000002
#
# analyze_spectra
# Min Timestamp 1531264658574
# Max Timestamp 1531264665486
# Max Billed Duration 17000 milliseconds
# Total Billed Duration 400900 milliseconds
# Cost 0.006683003000000001
#
# Combine Spectra
# Timestamp 1531264665949
# Billed Duration 5000 milliseconds
# Max Memory Used 77
# Cost 2.085e-05
#
# Percolator Spectra
# Timestamp 1531264722584
# Billed Duration 52100 milliseconds
# Max Memory Used 540
# Cost 0.002551337
#
# END RESULTS
# Total Cost 0.009390217000000001
# Total Runtime 85.53592486381531 seconds
# Total Billed Duration 466.1 seconds
# Total Memory Used 20572 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264639.408143-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# spectra-1531264786.457250-1-1-1.ms2 last modified 1531264787000.0
# 19:19:50: Waiting for spectra function...
# 19:20:20: Waiting for spectra function...
# 19:20:51: Found spectra function
# 19:20:51: Waiting for percolator.decoy functions...
# 19:21:22: Found percolator.decoy functions
# 19:21:22: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264797923
# Billed Duration 8000 milliseconds
# Max Memory Used 579
# Cost 0.00013336
#
# analyze_spectra
# Min Timestamp 1531264806072
# Max Timestamp 1531264814866
# Max Billed Duration 19500 milliseconds
# Total Billed Duration 402600 milliseconds
# Cost 0.006711342
#
# Combine Spectra
# Timestamp 1531264815400
# Billed Duration 7400 milliseconds
# Max Memory Used 79
# Cost 3.0858e-05
#
# Percolator Spectra
# Timestamp 1531264874084
# Billed Duration 51700 milliseconds
# Max Memory Used 540
# Cost 0.002531749
#
# END RESULTS
# Total Cost 0.009407308999999999
# Total Runtime 89.87976512908935 seconds
# Total Billed Duration 469.7 seconds
# Total Memory Used 20608 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264786.457250-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# spectra-1531264934.231714-1-1-1.ms2 last modified 1531264935000.0
# 19:22:17: Waiting for spectra function...
# 19:22:48: Found spectra function
# 19:22:48: Waiting for percolator.decoy functions...
# 19:23:19: Waiting for percolator.decoy functions...
# 19:23:50: Found percolator.decoy functions
# 19:23:50: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531264945860
# Billed Duration 8400 milliseconds
# Max Memory Used 579
# Cost 0.000140028
#
# analyze_spectra
# Min Timestamp 1531264953451
# Max Timestamp 1531264960272
# Max Billed Duration 17400 milliseconds
# Total Billed Duration 403400 milliseconds
# Cost 0.006724678
#
# Combine Spectra
# Timestamp 1531264960600
# Billed Duration 4800 milliseconds
# Max Memory Used 81
# Cost 2.0016e-05
#
# Percolator Spectra
# Timestamp 1531265015793
# Billed Duration 51200 milliseconds
# Max Memory Used 540
# Cost 0.002507264
#
# END RESULTS
# Total Cost 0.009391986000000001
# Total Runtime 84.91340379714966 seconds
# Total Billed Duration 467.8 seconds
# Total Memory Used 20630 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531264934.231714-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# spectra-1531265080.314590-1-1-1.ms2 last modified 1531265081000.0
# 19:24:44: Waiting for spectra function...
# 19:25:14: Found spectra function
# 19:25:15: Waiting for percolator.decoy functions...
# 19:25:45: Waiting for percolator.decoy functions...
# 19:26:15: Found percolator.decoy functions
# 19:26:16: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531265091954
# Billed Duration 8300 milliseconds
# Max Memory Used 579
# Cost 0.000138361
#
# analyze_spectra
# Min Timestamp 1531265099277
# Max Timestamp 1531265106752
# Max Billed Duration 17700 milliseconds
# Total Billed Duration 404300 milliseconds
# Cost 0.006739681
#
# Combine Spectra
# Timestamp 1531265107108
# Billed Duration 4000 milliseconds
# Max Memory Used 77
# Cost 1.668e-05
#
# Percolator Spectra
# Timestamp 1531265160825
# Billed Duration 50200 milliseconds
# Max Memory Used 528
# Cost 0.0024582939999999998
#
# END RESULTS
# Total Cost 0.009353015999999999
# Total Runtime 83.43160886764527 seconds
# Total Billed Duration 466.8 seconds
# Total Memory Used 20629 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531265080.314590-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# spectra-1531265230.698253-1-1-1.ms2 last modified 1531265232000.0
# 19:27:14: Waiting for spectra function...
# 19:27:45: Found spectra function
# 19:27:45: Waiting for percolator.decoy functions...
# 19:28:15: Waiting for percolator.decoy functions...
# 19:28:46: Found percolator.decoy functions
# 19:28:46: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531265242517
# Billed Duration 8600 milliseconds
# Max Memory Used 579
# Cost 0.00014336200000000001
#
# analyze_spectra
# Min Timestamp 1531265248574
# Max Timestamp 1531265258286
# Max Billed Duration 16100 milliseconds
# Total Billed Duration 398900 milliseconds
# Cost 0.006649663
#
# Combine Spectra
# Timestamp 1531265258460
# Billed Duration 5300 milliseconds
# Max Memory Used 80
# Cost 2.2101e-05
#
# Percolator Spectra
# Timestamp 1531265314385
# Billed Duration 50600 milliseconds
# Max Memory Used 530
# Cost 0.002477882
#
# END RESULTS
# Total Cost 0.009293008
# Total Runtime 83.81828818321227 seconds
# Total Billed Duration 463.4 seconds
# Total Memory Used 20653 MB
# bucket maccoss-human-split-spectra expected 28797 actual 0
# bucket maccoss-human-sort-spectra expected 28797 actual 0
# bucket maccoss-human-merge-spectra expected 28797 actual 28760
# key spectra-1531265230.698253-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 10036
# key percolator.target.psms.txt expected 13325 actual 13473
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 29 merge objects
# Deleted 29 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 4.790225219726563 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.00014286190000000002
# Total Runtime 8.57 seconds
# Total Billed Duration 8.57 seconds
# Total Memory Used 563.5 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.0067178433
# Total Runtime 17.51 seconds
# Total Billed Duration 402.99 seconds
# Total Memory Used 19249.2 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 2.1600600000000005e-05
# Total Runtime 5.18 seconds
# Total Billed Duration 5.18 seconds
# Total Memory Used 77.2 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0024817996
# Total Runtime 50.68 seconds
# Total Billed Duration 50.68 seconds
# Total Memory Used 533.7 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.009364105400000001
# Total Runtime 86.73022521972656 seconds
# Total Billed Duration 467.42 seconds
# Total Memory Used 20423.6 MB

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Test merge benchmark on Lambda for small file")

params = json.loads("""{
  "input_name": "20170403_HelaQC_01.ms2",
  "iterations": 10,
  "lambda": true,
  "merge": true,
  "region": "us-west-2",
  "sort": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "cost": 0.0464,
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 50000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": 5000,
    "chunk_size": 500000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

""")
benchmark.run(params)
# Out:
# Test merge benchmark on Lambda for small file
# Current Git commit 6f6fc52 benchmark: Add support for merge and unmerge versions
#
#
# Iteration 0
# spectra-1531283623.593789-1-1-1.ms2 last modified 1531283625000.0
# 00:33:47: Waiting for spectra function...
# 00:34:18: Waiting for spectra function...
# 00:34:48: Waiting for spectra function...
# 00:35:19: Waiting for spectra function...
# 00:35:49: Waiting for spectra function...
# 00:36:20: Waiting for spectra function...
# 00:36:50: Waiting for spectra function...
# 00:37:20: Waiting for spectra function...
# 00:37:51: Waiting for spectra function...
# 00:38:21: Waiting for spectra function...
# 00:38:52: Found spectra function
# 00:38:52: Waiting for percolator.decoy functions...
# 00:39:23: Waiting for percolator.decoy functions...
# 00:39:53: Found percolator.decoy functions
# 00:39:54: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531283635894
# Billed Duration 8600 milliseconds
# Max Memory Used 423
# Cost 0.000421142
#
# sort_spectra
# Min Timestamp 1531283703274
# Max Timestamp 1531283883072
# Max Billed Duration 251000 milliseconds
# Total Billed Duration 1154700 milliseconds
# Cost 0.019248849000000002
#
# merge_spectra
# Min Timestamp 1531283800651
# Max Timestamp 1531283893454
# Max Billed Duration 189900 milliseconds
# Total Billed Duration 190600 milliseconds
# Cost 0.0031773020000000003
#
# analyze_spectra
# Min Timestamp 1531283907310
# Max Timestamp 1531283915165
# Max Billed Duration 27900 milliseconds
# Total Billed Duration 132200 milliseconds
# Cost 0.002203774
#
# Combine Spectra
# Timestamp 1531283915434
# Billed Duration 4400 milliseconds
# Max Memory Used 93
# Cost 1.8348e-05
#
# Percolator Spectra
# Timestamp 1531283971151
# Billed Duration 51100 milliseconds
# Max Memory Used 520
# Cost 0.002502367
#
# END RESULTS
# Total Cost 0.027571782000000003
# Total Runtime 536.1951843738556 seconds
# Total Billed Duration 1541.6 seconds
# Total Memory Used 6268 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531283623.593789-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531283623.593789-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# spectra-1531284076.332198-1-1-1.ms2 last modified 1531284077000.0
# 00:41:21: Waiting for spectra function...
# 00:41:51: Waiting for spectra function...
# 00:42:22: Waiting for spectra function...
# 00:42:52: Waiting for spectra function...
# 00:43:23: Waiting for spectra function...
# 00:43:53: Waiting for spectra function...
# 00:44:24: Waiting for spectra function...
# 00:44:54: Waiting for spectra function...
# 00:45:24: Waiting for spectra function...
# 00:45:55: Waiting for spectra function...
# 00:46:26: Waiting for spectra function...
# 00:46:56: Found spectra function
# 00:46:56: Waiting for percolator.decoy functions...
# 00:47:27: Waiting for percolator.decoy functions...
# 00:47:57: Found percolator.decoy functions
# 00:47:58: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531284085981
# Billed Duration 5400 milliseconds
# Max Memory Used 464
# Cost 0.000264438
#
# sort_spectra
# Min Timestamp 1531284148745
# Max Timestamp 1531284376489
# Max Billed Duration 292500 milliseconds
# Total Billed Duration 1236400 milliseconds
# Cost 0.020610788
#
# merge_spectra
# Min Timestamp 1531284231395
# Max Timestamp 1531284385458
# Max Billed Duration 236800 milliseconds
# Total Billed Duration 237300 milliseconds
# Cost 0.003955791
#
# analyze_spectra
# Min Timestamp 1531284398929
# Max Timestamp 1531284407877
# Max Billed Duration 28000 milliseconds
# Total Billed Duration 128700 milliseconds
# Cost 0.002145429
#
# Combine Spectra
# Timestamp 1531284408240
# Billed Duration 4000 milliseconds
# Max Memory Used 94
# Cost 1.668e-05
#
# Percolator Spectra
# Timestamp 1531284463343
# Billed Duration 51300 milliseconds
# Max Memory Used 524
# Cost 0.0025121609999999997
#
# END RESULTS
# Total Cost 0.029505287
# Total Runtime 622.191837310791 seconds
# Total Billed Duration 1663.1 seconds
# Total Memory Used 6504 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531284076.332198-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531284076.332198-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# spectra-1531284554.958686-1-1-1.ms2 last modified 1531284556000.0
# 00:49:18: Waiting for spectra function...
# 00:49:49: Waiting for spectra function...
# 00:50:19: Waiting for spectra function...
# 00:50:50: Waiting for spectra function...
# 00:51:20: Waiting for spectra function...
# 00:51:51: Waiting for spectra function...
# 00:52:21: Waiting for spectra function...
# 00:52:52: Waiting for spectra function...
# 00:53:22: Waiting for spectra function...
# 00:53:53: Waiting for spectra function...
# 00:54:23: Waiting for spectra function...
# 00:54:54: Found spectra function
# 00:54:54: Waiting for percolator.decoy functions...
# 00:55:25: Found percolator.decoy functions
# 00:55:25: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531284564047
# Billed Duration 5800 milliseconds
# Max Memory Used 506
# Cost 0.000284026
#
# sort_spectra
# Min Timestamp 1531284627026
# Max Timestamp 1531284830678
# Max Billed Duration 268400 milliseconds
# Total Billed Duration 1165700 milliseconds
# Cost 0.019432219
#
# merge_spectra
# Min Timestamp 1531284710831
# Max Timestamp 1531284838274
# Max Billed Duration 211300 milliseconds
# Total Billed Duration 211800 milliseconds
# Cost 0.003530706
#
# analyze_spectra
# Min Timestamp 1531284851801
# Max Timestamp 1531284860326
# Max Billed Duration 28200 milliseconds
# Total Billed Duration 132500 milliseconds
# Cost 0.002208775
#
# Combine Spectra
# Timestamp 1531284860585
# Billed Duration 3800 milliseconds
# Max Memory Used 94
# Cost 1.5846e-05
#
# Percolator Spectra
# Timestamp 1531284915302
# Billed Duration 50900 milliseconds
# Max Memory Used 526
# Cost 0.002492573
#
# END RESULTS
# Total Cost 0.027964145000000003
# Total Runtime 571.5511096954345 seconds
# Total Billed Duration 1570.5 seconds
# Total Memory Used 6614 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531284554.958686-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531284554.958686-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# spectra-1531285003.280563-1-1-1.ms2 last modified 1531285004000.0
# 00:56:46: Waiting for spectra function...
# 00:57:17: Waiting for spectra function...
# 00:57:47: Waiting for spectra function...
# 00:58:18: Waiting for spectra function...
# 00:58:48: Waiting for spectra function...
# 00:59:19: Waiting for spectra function...
# 00:59:49: Waiting for spectra function...
# 01:00:20: Waiting for spectra function...
# 01:00:50: Waiting for spectra function...
# 01:01:21: Waiting for spectra function...
# 01:01:51: Found spectra function
# 01:01:52: Waiting for percolator.decoy functions...
# 01:02:22: Waiting for percolator.decoy functions...
# 01:02:53: Found percolator.decoy functions
# 01:02:53: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531285012407
# Billed Duration 6000 milliseconds
# Max Memory Used 507
# Cost 0.00029382
#
# sort_spectra
# Min Timestamp 1531285076508
# Max Timestamp 1531285262706
# Max Billed Duration 252900 milliseconds
# Total Billed Duration 1165700 milliseconds
# Cost 0.019432219
# merge_spectra
# Min Timestamp 1531285159952
# Max Timestamp 1531285273335
# Max Billed Duration 196900 milliseconds
# Total Billed Duration 197400 milliseconds
# Cost 0.003290658
#
# analyze_spectra
# Min Timestamp 1531285286314
# Max Timestamp 1531285295178
# Max Billed Duration 28400 milliseconds
# Total Billed Duration 127300 milliseconds
# Cost 0.002122091
#
# Combine Spectra
# Timestamp 1531285295438
# Billed Duration 4700 milliseconds
# Max Memory Used 94
# Cost 1.9599e-05
#
# Percolator Spectra
# Timestamp 1531285353128
# Billed Duration 53200 milliseconds
# Max Memory Used 527
# Cost 0.002605204
#
# END RESULTS
# Total Cost 0.027763591
# Total Runtime 545.1053250789643 seconds
# Total Billed Duration 1554.3 seconds
# Total Memory Used 6662 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531285003.280563-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531285003.280563-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# spectra-1531285448.824783-1-1-1.ms2 last modified 1531285450000.0
# 01:04:12: Waiting for spectra function...
# 01:04:43: Waiting for spectra function...
# 01:05:13: Waiting for spectra function...
# 01:05:44: Waiting for spectra function...
# 01:06:14: Waiting for spectra function...
# 01:06:45: Waiting for spectra function...
# 01:07:15: Waiting for spectra function...
# 01:07:46: Waiting for spectra function...
# 01:08:16: Waiting for spectra function...
# 01:08:47: Waiting for spectra function...
# 01:09:17: Found spectra function
# 01:09:18: Waiting for percolator.decoy functions...
# 01:09:48: Found percolator.decoy functions
# 01:09:49: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531285458563
# Billed Duration 6400 milliseconds
# Max Memory Used 508
# Cost 0.000313408
#
# sort_spectra
# Min Timestamp 1531285557734
# Max Timestamp 1531285690019
# Max Billed Duration 232900 milliseconds
# Total Billed Duration 1112700 milliseconds
# Cost 0.018548709
#
# merge_spectra
# Min Timestamp 1531285639995
# Max Timestamp 1531285701638
# Max Billed Duration 144100 milliseconds
# Total Billed Duration 144600 milliseconds
# Cost 0.0024104820000000002
#
# analyze_spectra
# Min Timestamp 1531285714805
# Max Timestamp 1531285723998
# Max Billed Duration 29800 milliseconds
# Total Billed Duration 133100 milliseconds
# Cost 0.0022187770000000003
#
# Combine Spectra
# Timestamp 1531285724234
# Billed Duration 3900 milliseconds
# Max Memory Used 97
# Cost 1.6263e-05
#
# Percolator Spectra
# Timestamp 1531285779923
# Billed Duration 51900 milliseconds
# Max Memory Used 528
# Cost 0.002541543
#
# END RESULTS
# Total Cost 0.026049182000000004
# Total Runtime 472.29503631591797 seconds
# Total Billed Duration 1452.6 seconds
# Total Memory Used 6744 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531285448.824783-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531285448.824783-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# spectra-1531285863.965179-1-1-1.ms2 last modified 1531285865000.0
# 01:11:07: Waiting for spectra function...
# 01:11:38: Waiting for spectra function...
# 01:12:08: Waiting for spectra function...
# 01:12:39: Waiting for spectra function...
# 01:13:09: Waiting for spectra function...
# 01:13:39: Waiting for spectra function...
# 01:14:10: Waiting for spectra function...
# 01:14:40: Waiting for spectra function...
# 01:15:11: Waiting for spectra function...
# 01:15:41: Waiting for spectra function...
# 01:16:12: Waiting for spectra function...
# 01:16:42: Found spectra function
# 01:16:43: Waiting for percolator.decoy functions...
# 01:17:13: Found percolator.decoy functions
# 01:17:14: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531285872159
# Billed Duration 5100 milliseconds
# Max Memory Used 515
# Cost 0.000249747
#
# sort_spectra
# Min Timestamp 1531285949075
# Max Timestamp 1531286140757
# Max Billed Duration 270700 milliseconds
# Total Billed Duration 1204200 milliseconds
# Cost 0.020074014
#
# merge_spectra
# Min Timestamp 1531286023887
# Max Timestamp 1531286152436
# Max Billed Duration 203400 milliseconds
# Total Billed Duration 203900 milliseconds
# Cost 0.003399013
#
# analyze_spectra
# Min Timestamp 1531286165058
# Max Timestamp 1531286173253
# Max Billed Duration 28100 milliseconds
# Total Billed Duration 125200 milliseconds
# Cost 0.002087084
#
# Combine Spectra
# Timestamp 1531286173516
# Billed Duration 4500 milliseconds
# Max Memory Used 93
# Cost 1.8765e-05
#
# Percolator Spectra
# Timestamp 1531286228842
# Billed Duration 51000 milliseconds
# Max Memory Used 528
# Cost 0.00249747
#
# END RESULTS
# Total Cost 0.028326093000000004
# Total Runtime 565.7960911273956 seconds
# Total Billed Duration 1593.9 seconds
# Total Memory Used 6642 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531285863.965179-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531285863.965179-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# spectra-1531286309.351006-1-1-1.ms2 last modified 1531286310000.0
# 01:18:33: Waiting for spectra function...
# 01:19:03: Waiting for spectra function...
# 01:19:34: Waiting for spectra function...
# 01:20:04: Waiting for spectra function...
# 01:20:35: Waiting for spectra function...
# 01:21:05: Waiting for spectra function...
# 01:21:36: Waiting for spectra function...
# 01:22:06: Waiting for spectra function...
# 01:22:37: Waiting for spectra function...
# 01:23:07: Waiting for spectra function...
# 01:23:38: Waiting for spectra function...
# 01:24:08: Found spectra function
# 01:24:09: Waiting for percolator.decoy functions...
# 01:24:39: Waiting for percolator.decoy functions...
# 01:25:10: Found percolator.decoy functions
# 01:25:10: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531286319200
# Billed Duration 6400 milliseconds
# Max Memory Used 515
# Cost 0.000313408
#
# sort_spectra
# Min Timestamp 1531286392835
# Max Timestamp 1531286597580
# Max Billed Duration 280700 milliseconds
# Total Billed Duration 1238700 milliseconds
# Cost 0.020649129000000002
#
# merge_spectra
# Min Timestamp 1531286477636
# Max Timestamp 1531286612054
# Max Billed Duration 219300 milliseconds
# Total Billed Duration 219800 milliseconds
# Cost 0.003664066
#
# analyze_spectra
# Min Timestamp 1531286623181
# Max Timestamp 1531286631908
# Max Billed Duration 28800 milliseconds
# Total Billed Duration 128800 milliseconds
# Cost 0.0021470960000000002
#
# Combine Spectra
# Timestamp 1531286632157
# Billed Duration 4100 milliseconds
# Max Memory Used 93
# Cost 1.7097e-05
#
# Percolator Spectra
# Timestamp 1531286687202
# Billed Duration 51100 milliseconds
# Max Memory Used 529
# Cost 0.002502367
#
# END RESULTS
# Total Cost 0.029293163000000004
# Total Runtime 593.7176333904266 seconds
# Total Billed Duration 1648.9 seconds
# Total Memory Used 6652 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531286309.351006-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531286309.351006-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# spectra-1531286782.799233-1-1-1.ms2 last modified 1531286784000.0
# 01:26:26: Waiting for spectra function...
# 01:26:57: Waiting for spectra function...
# 01:27:27: Waiting for spectra function...
# 01:27:58: Waiting for spectra function...
# 01:28:28: Waiting for spectra function...
# 01:28:59: Waiting for spectra function...
# 01:29:29: Waiting for spectra function...
# 01:30:00: Waiting for spectra function...
# 01:30:30: Waiting for spectra function...
# 01:31:01: Waiting for spectra function...
# 01:31:31: Waiting for spectra function...
# 01:32:02: Found spectra function
# 01:32:02: Waiting for percolator.decoy functions...
# 01:32:33: Found percolator.decoy functions
# 01:32:33: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531286792199
# Billed Duration 5900 milliseconds
# Max Memory Used 519
# Cost 0.000288923
#
# sort_spectra
# Min Timestamp 1531286866150
# Max Timestamp 1531287070917
# Max Billed Duration 280500 milliseconds
# Total Billed Duration 1236500 milliseconds
# Cost 0.020612455000000002
#
# merge_spectra
# Min Timestamp 1531286950384
# Max Timestamp 1531287084258
# Max Billed Duration 218200 milliseconds
# Total Billed Duration 218700 milliseconds
# Cost 0.0036457290000000003
#
# analyze_spectra
# Min Timestamp 1531287095462
# Max Timestamp 1531287102409
# Max Billed Duration 26000 milliseconds
# Total Billed Duration 126100 milliseconds
# Cost 0.0021020870000000003
#
# Combine Spectra
# Timestamp 1531287102494
# Billed Duration 5100 milliseconds
# Max Memory Used 97
# Cost 2.1266999999999998e-05
#
# Percolator Spectra
# Timestamp 1531287159437
# Billed Duration 52100 milliseconds
# Max Memory Used 530
# Cost 0.002551337
#
# END RESULTS
# Total Cost 0.029221798
# Total Runtime 591.2006984233856 seconds
# Total Billed Duration 1644.4 seconds
# Total Memory Used 6729 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531286782.799233-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531286782.799233-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# spectra-1531287229.591027-1-1-1.ms2 last modified 1531287230000.0
# 01:33:53: Waiting for spectra function...
# 01:34:24: Waiting for spectra function...
# 01:34:54: Waiting for spectra function...
# 01:35:25: Waiting for spectra function...
# 01:35:55: Waiting for spectra function...
# 01:36:25: Waiting for spectra function...
# 01:36:56: Waiting for spectra function...
# 01:37:26: Waiting for spectra function...
# 01:37:57: Waiting for spectra function...
# 01:38:27: Found spectra function
# 01:38:28: Waiting for percolator.decoy functions...
# 01:38:58: Waiting for percolator.decoy functions...
# 01:39:29: Found percolator.decoy functions
# 01:39:29: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531287238953
# Billed Duration 6100 milliseconds
# Max Memory Used 519
# Cost 0.000298717
#
# sort_spectra
# Min Timestamp 1531287339789
# Max Timestamp 1531287469024
# Max Billed Duration 231200 milliseconds
# Total Billed Duration 1150900 milliseconds
# Cost 0.019185503
#
# merge_spectra
# Min Timestamp 1531287411435
# Max Timestamp 1531287480156
# Max Billed Duration 140500 milliseconds
# Total Billed Duration 141000 milliseconds
# Cost 0.0023504700000000003
#
# analyze_spectra
# Min Timestamp 1531287491582
# Max Timestamp 1531287498959
# Max Billed Duration 25100 milliseconds
# Total Billed Duration 118200 milliseconds
# Cost 0.0019703940000000003
#
# Combine Spectra
# Timestamp 1531287499197
# Billed Duration 4000 milliseconds
# Max Memory Used 97
# Cost 1.668e-05
#
# Percolator Spectra
# Timestamp 1531287557191
# Billed Duration 51200 milliseconds
# Max Memory Used 520
# Cost 0.002507264
#
# END RESULTS
# Total Cost 0.026329028
# Total Runtime 461.2930103302002 seconds
# Total Billed Duration 1471.4 seconds
# Total Memory Used 6786 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531287229.591027-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531287229.591027-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# spectra-1531287647.467122-1-1-1.ms2 last modified 1531287648000.0
# 01:40:51: Waiting for spectra function...
# 01:41:21: Waiting for spectra function...
# 01:41:52: Waiting for spectra function...
# 01:42:22: Waiting for spectra function...
# 01:42:53: Waiting for spectra function...
# 01:43:23: Waiting for spectra function...
# 01:43:54: Waiting for spectra function...
# 01:44:24: Waiting for spectra function...
# 01:44:55: Waiting for spectra function...
# 01:45:25: Waiting for spectra function...
# 01:45:55: Found spectra function
# 01:45:56: Waiting for percolator.decoy functions...
# 01:46:27: Waiting for percolator.decoy functions...
# 01:46:57: Found percolator.decoy functions
# 01:46:57: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531287656049
# Billed Duration 5400 milliseconds
# Max Memory Used 519
# Cost 0.000264438
#
# sort_spectra
# Min Timestamp 1531287756985
# Max Timestamp 1531287916850
# Max Billed Duration 262500 milliseconds
# Total Billed Duration 1121700 milliseconds
# Cost 0.018698739000000002
#
# merge_spectra
# Min Timestamp 1531287807581
# Max Timestamp 1531287927735
# Max Billed Duration 170900 milliseconds
# Total Billed Duration 171400 milliseconds
# Cost 0.0028572380000000002
#
# analyze_spectra
# Min Timestamp 1531287940382
# Max Timestamp 1531287948816
# Max Billed Duration 28500 milliseconds
# Total Billed Duration 128000 milliseconds
# Cost 0.00213376
#
# Combine Spectra
# Timestamp 1531287949042
# Billed Duration 4700 milliseconds
# Max Memory Used 93
# Cost 1.9599e-05
#
# Percolator Spectra
# Timestamp 1531287996665
# Billed Duration 43200 milliseconds
# Max Memory Used 539
# Cost 0.002115504
#
# END RESULTS
# Total Cost 0.026089278
# Total Runtime 518.2475974082947 seconds
# Total Billed Duration 1474.4 seconds
# Total Memory Used 7116 MB
# bucket maccoss-human-split-spectra expected 28797 actual 28760
# bucket maccoss-human-sort-spectra expected 28797 actual 28759
# bucket maccoss-human-merge-spectra expected 28797 actual 28759
# spectra-1531287647.467122-6-58670073-58670073.ms2 split 3760 sort 3759
# key spectra-1531287647.467122-1-1-1.txt expected 135041 actual 134842
# key percolator.target.peptides.txt expected 9858 actual 9787
# key percolator.target.psms.txt expected 13325 actual 13121
# Deleted 1 input objects
# Deleted 6 split objects
# Deleted 6 sort objects
# Deleted 6 merge objects
# Deleted 6 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 3.2893523454666136 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.0002992067
# Total Runtime 6.11 seconds
# Total Billed Duration 6.11 seconds
# Total Memory Used 499.5 MB
#
# AVERAGE SORT RESULTS
# Total Cost 0.0196492624
# Total Runtime 262.33 seconds
# Total Billed Duration 1178.72 seconds
# Total Memory Used 1129.3 MB
#
# AVERAGE MERGE RESULTS
# Total Cost 0.0032281455
# Total Runtime 193.13 seconds
# Total Billed Duration 193.65 seconds
# Total Memory Used 304.5 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.0021339266999999993
# Total Runtime 27.88 seconds
# Total Billed Duration 128.01 seconds
# Total Memory Used 4116.8 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 1.80144e-05
# Total Runtime 4.32 seconds
# Total Billed Duration 4.32 seconds
# Total Memory Used 94.5 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.002482779
# Total Runtime 50.7 seconds
# Total Billed Duration 50.7 seconds
# Total Memory Used 527.1 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.027811334700000002
# Total Runtime 547.7593523454666 seconds
# Total Billed Duration 1561.51 seconds
# Total Memory Used 6671.7 MB

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)


print("Test non-merge benchmark on Lambda for large file")

params = json.loads("""{
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "lambda": true,
  "merge": false,
  "region": "us-west-2",
  "sort": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "cost": 0.0464,
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 5000,
    "chunk_size": 50000000,
    "memory_size": 1024,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 1024,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": 5000,
    "chunk_size": 500000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}

""")
benchmark.run(params)
# Out:
# Test non-merge benchmark on Lambda for large file
# Current Git commit 6f6fc52 benchmark: Add support for merge and unmerge versions
#
#
# Iteration 0
# spectra-1531277119.694464-1-1-1.ms2 last modified 1531277122000.0
# 22:45:59: Waiting for spectra function...
# 22:46:29: Waiting for spectra function...
# 22:46:59: Waiting for spectra function...
# 22:47:30: Waiting for spectra function...
# 22:48:00: Waiting for spectra function...
# 22:48:31: Waiting for spectra function...
# 22:49:01: Found spectra function
# 22:49:01: Waiting for percolator.decoy functions...
# 22:49:32: Waiting for percolator.decoy functions...
# 22:50:02: Found percolator.decoy functions
# 22:50:03: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531277281164
# Billed Duration 122200 milliseconds
# Max Memory Used 1017
# Cost 0.0020370740000000003
#
# analyze_spectra
# Min Timestamp 1531277203114
# Max Timestamp 1531277307237
# Max Billed Duration 42600 milliseconds
# Total Billed Duration 337400 milliseconds
# Cost 0.005624458000000001
#
# Combine Spectra
# Timestamp 1531277307564
# Billed Duration 7500 milliseconds
# Max Memory Used 146
# Cost 3.1275e-05
#
# Percolator Spectra
# Timestamp 1531277379686
# Billed Duration 64500 milliseconds
# Max Memory Used 873
# Cost 0.003158565
#
# END RESULTS
# Total Cost 0.010851372
# Total Runtime 275.57601146698 seconds
# Total Billed Duration 531.6 seconds
# Total Memory Used 13300 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531277119.694464-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# spectra-1531277527.668482-1-1-1.ms2 last modified 1531277530000.0
# 22:52:50: Waiting for spectra function...
# 22:53:20: Waiting for spectra function...
# 22:53:51: Waiting for spectra function...
# 22:54:21: Waiting for spectra function...
# 22:54:52: Waiting for spectra function...
# 22:55:22: Waiting for spectra function...
# 22:55:52: Found spectra function
# 22:55:53: Waiting for percolator.decoy functions...
# 22:56:23: Waiting for percolator.decoy functions...
# 22:56:54: Found percolator.decoy functions
# 22:56:54: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531277689901
# Billed Duration 119900 milliseconds
# Max Memory Used 1017
# Cost 0.001998733
#
# analyze_spectra
# Min Timestamp 1531277610952
# Max Timestamp 1531277715958
# Max Billed Duration 42800 milliseconds
# Total Billed Duration 334400 milliseconds
# Cost 0.005574448
#
# Combine Spectra
# Timestamp 1531277716203
# Billed Duration 7800 milliseconds
# Max Memory Used 146
# Cost 3.2526e-05
#
# Percolator Spectra
# Timestamp 1531277787943
# Billed Duration 64100 milliseconds
# Max Memory Used 877
# Cost 0.003138977
#
# END RESULTS
# Total Cost 0.010744684
# Total Runtime 276.7866719722748 seconds
# Total Billed Duration 526.2 seconds
# Total Memory Used 13304 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531277527.668482-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# spectra-1531277958.885275-1-1-1.ms2 last modified 1531277961000.0
# 23:00:22: Waiting for spectra function...
# 23:00:52: Waiting for spectra function...
# 23:01:22: Waiting for spectra function...
# 23:01:53: Waiting for spectra function...
# 23:02:23: Waiting for spectra function...
# 23:02:54: Waiting for spectra function...
# 23:03:24: Found spectra function
# 23:03:25: Waiting for percolator.decoy functions...
# 23:03:55: Waiting for percolator.decoy functions...
# 23:04:26: Found percolator.decoy functions
# 23:04:26: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531278144044
# Billed Duration 122300 milliseconds
# Max Memory Used 1017
# Cost 0.002038741
#
# analyze_spectra
# Min Timestamp 1531278066539
# Max Timestamp 1531278169815
# Max Billed Duration 41500 milliseconds
# Total Billed Duration 334700 milliseconds
# Cost 0.005579449
#
# Combine Spectra
# Timestamp 1531278170044
# Billed Duration 6500 milliseconds
# Max Memory Used 146
# Cost 2.7105e-05
#
# Percolator Spectra
# Timestamp 1531278240301
# Billed Duration 63900 milliseconds
# Max Memory Used 879
# Cost 0.003129183
#
# END RESULTS
# Total Cost 0.010774478
# Total Runtime 296.8900084018707 seconds
# Total Billed Duration 527.4 seconds
# Total Memory Used 13306 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531277958.885275-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 3
# spectra-1531278391.827034-1-1-1.ms2 last modified 1531278394000.0
# 23:07:34: Waiting for spectra function...
# 23:08:05: Waiting for spectra function...
# 23:08:35: Waiting for spectra function...
# 23:09:05: Waiting for spectra function...
# 23:09:36: Waiting for spectra function...
# 23:10:06: Waiting for spectra function...
# 23:10:37: Found spectra function
# 23:10:37: Waiting for percolator.decoy functions...
# 23:11:07: Waiting for percolator.decoy functions...
# 23:11:38: Found percolator.decoy functions
# 23:11:38: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531278576625
# Billed Duration 122400 milliseconds
# Max Memory Used 1017
# Cost 0.002040408
#
# analyze_spectra
# Min Timestamp 1531278496935
# Max Timestamp 1531278606298
# Max Billed Duration 47300 milliseconds
# Total Billed Duration 349800 milliseconds
# Cost 0.0058311660000000005
#
# Combine Spectra
# Timestamp 1531278606646
# Billed Duration 7700 milliseconds
# Max Memory Used 146
# Cost 3.2109e-05
#
# Percolator Spectra
# Timestamp 1531278677966
# Billed Duration 63800 milliseconds
# Max Memory Used 882
# Cost 0.003124286
#
# END RESULTS
# Total Cost 0.011027969000000002
# Total Runtime 303.3926085948944 seconds
# Total Billed Duration 543.7 seconds
# Total Memory Used 13309 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531278391.827034-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 4
# spectra-1531278837.035508-1-1-1.ms2 last modified 1531278839000.0
# 23:14:36: Waiting for spectra function...
# 23:15:06: Waiting for spectra function...
# 23:15:36: Waiting for spectra function...
# 23:16:07: Waiting for spectra function...
# 23:16:37: Waiting for spectra function...
# 23:17:08: Waiting for spectra function...
# 23:17:39: Waiting for spectra function...
# 23:18:09: Waiting for spectra function...
# 23:18:39: Waiting for spectra function...
# 23:19:10: Waiting for spectra function...
# 23:19:40: Found spectra function
# 23:19:41: Waiting for percolator.decoy functions...
# 23:20:11: Waiting for percolator.decoy functions...
# 23:20:42: Found percolator.decoy functions
# 23:20:42: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531278952031
# Billed Duration 76300 milliseconds
# Max Memory Used 1024
# Cost 0.001271921
#
# analyze_spectra
# Min Timestamp 1531278920127
# Max Timestamp 1531279163959
# Max Billed Duration 32100 milliseconds
# Total Billed Duration 334400 milliseconds
# Cost 0.005574448
#
# Combine Spectra
# Timestamp 1531279164182
# Billed Duration 7900 milliseconds
# Max Memory Used 146
# Cost 3.2943e-05
#
# Percolator Spectra
# Timestamp 1531279235746
# Billed Duration 63900 milliseconds
# Max Memory Used 883
# Cost 0.003129183
#
# END RESULTS
# Total Cost 0.010008495
# Total Runtime 218.7599739551544 seconds
# Total Billed Duration 482.5 seconds
# Total Memory Used 13317 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531278837.035508-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 5
# spectra-1531279409.471020-1-1-1.ms2 last modified 1531279412000.0
# 23:24:08: Waiting for spectra function...
# 23:24:38: Waiting for spectra function...
# 23:25:09: Waiting for spectra function...
# 23:25:39: Waiting for spectra function...
# 23:26:09: Waiting for spectra function...
# 23:26:40: Found spectra function
# 23:26:40: Waiting for percolator.decoy functions...
# 23:27:11: Waiting for percolator.decoy functions...
# 23:27:42: Found percolator.decoy functions
# 23:27:42: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531279561305
# Billed Duration 113500 milliseconds
# Max Memory Used 1017
# Cost 0.0018920450000000002
#
# analyze_spectra
# Min Timestamp 1531279490977
# Max Timestamp 1531279590636
# Max Billed Duration 44500 milliseconds
# Total Billed Duration 344100 milliseconds
# Cost 0.0057361470000000005
#
# Combine Spectra
# Timestamp 1531279591085
# Billed Duration 6800 milliseconds
# Max Memory Used 146
# Cost 2.8355999999999998e-05
#
# Percolator Spectra
# Timestamp 1531279661176
# Billed Duration 63700 milliseconds
# Max Memory Used 884
# Cost 0.0031193889999999998
#
# END RESULTS
# Total Cost 0.010775937000000001
# Total Runtime 266.66060423851013 seconds
# Total Billed Duration 528.1 seconds
# Total Memory Used 13311 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531279409.471020-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 6
# spectra-1531279793.747228-1-1-1.ms2 last modified 1531279796000.0
# 23:30:32: Waiting for spectra function...
# 23:31:02: Waiting for spectra function...
# 23:31:33: Waiting for spectra function...
# 23:32:03: Waiting for spectra function...
# 23:32:34: Waiting for spectra function...
# 23:33:04: Waiting for spectra function...
# 23:33:34: Waiting for spectra function...
# 23:34:05: Waiting for spectra function...
# 23:34:35: Waiting for spectra function...
# 23:35:06: Waiting for spectra function...
# 23:35:36: Waiting for spectra function...
# 23:36:06: Waiting for spectra function...
# 23:36:37: Waiting for spectra function...
# 23:37:07: Waiting for spectra function...
# 23:37:38: Waiting for spectra function...
# 23:38:08: Found spectra function
# 23:38:09: Waiting for percolator.decoy functions...
# 23:38:39: Waiting for percolator.decoy functions...
# 23:39:09: Found percolator.decoy functions
# 23:39:10: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531279957920
# Billed Duration 125800 milliseconds
# Max Memory Used 1017
# Cost 0.002097086
#
# analyze_spectra
# Min Timestamp 1531279879761
# Max Timestamp 1531280274517
# Max Billed Duration 300000 milliseconds
# Total Billed Duration 640400 milliseconds
# Cost 0.010675468
#
# Combine Spectra
# Timestamp 1531280274826
# Billed Duration 7600 milliseconds
# Max Memory Used 146
# Cost 3.1692e-05
#
# Percolator Spectra
# Timestamp 1531280346346
# Billed Duration 64100 milliseconds
# Max Memory Used 885
# Cost 0.003138977
#
# END RESULTS
# Total Cost 0.015943223
# Total Runtime 535.6832866668701 seconds
# Total Billed Duration 837.9 seconds
# Total Memory Used 13313 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531279793.747228-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 7
# spectra-1531280499.993934-1-1-1.ms2 last modified 1531280502000.0
# 23:42:20: Waiting for spectra function...
# 23:42:50: Waiting for spectra function...
# 23:43:20: Waiting for spectra function...
# 23:43:51: Waiting for spectra function...
# 23:44:21: Waiting for spectra function...
# 23:44:52: Found spectra function
# 23:44:52: Waiting for percolator.decoy functions...
# 23:45:22: Waiting for percolator.decoy functions...
# 23:45:53: Waiting for percolator.decoy functions...
# 23:46:23: Found percolator.decoy functions
# 23:46:24: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531280656285
# Billed Duration 116400 milliseconds
# Max Memory Used 1017
# Cost 0.0019403880000000001
#
# analyze_spectra
# Min Timestamp 1531280581753
# Max Timestamp 1531280682574
# Max Billed Duration 34800 milliseconds
# Total Billed Duration 317400 milliseconds
# Cost 0.005291058
#
# Combine Spectra
# Timestamp 1531280682786
# Billed Duration 6600 milliseconds
# Max Memory Used 146
# Cost 2.7522e-05
#
# Percolator Spectra
# Timestamp 1531280754361
# Billed Duration 65000 milliseconds
# Max Memory Used 886
# Cost 0.0031830499999999998
#
# END RESULTS
# Total Cost 0.010442018
# Total Runtime 262.2739582538605 seconds
# Total Billed Duration 505.4 seconds
# Total Memory Used 13018 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531280499.993934-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 8
# spectra-1531280913.502271-1-1-1.ms2 last modified 1531280916000.0
# 23:49:13: Waiting for spectra function...
# 23:49:44: Waiting for spectra function...
# 23:50:14: Waiting for spectra function...
# 23:50:44: Waiting for spectra function...
# 23:51:15: Waiting for spectra function...
# 23:51:45: Found spectra function
# 23:51:46: Waiting for percolator.decoy functions...
# 23:52:16: Waiting for percolator.decoy functions...
# 23:52:46: Waiting for percolator.decoy functions...
# 23:53:17: Found percolator.decoy functions
# 23:53:17: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531281070143
# Billed Duration 117000 milliseconds
# Max Memory Used 1024
# Cost 0.0019503900000000002
#
# analyze_spectra
# Min Timestamp 1531280994552
# Max Timestamp 1531281095952
# Max Billed Duration 46000 milliseconds
# Total Billed Duration 339100 milliseconds
# Cost 0.005652797
#
# Combine Spectra
# Timestamp 1531281097044
# Billed Duration 8000 milliseconds
# Max Memory Used 146
# Cost 3.336e-05
#
# Percolator Spectra
# Timestamp 1531281168059
# Billed Duration 64100 milliseconds
# Max Memory Used 887
# Cost 0.003138977
#
# END RESULTS
# Total Cost 0.010775524
# Total Runtime 274.5829185009003 seconds
# Total Billed Duration 528.2 seconds
# Total Memory Used 13321 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531280913.502271-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 9
# spectra-1531281327.207525-1-1-1.ms2 last modified 1531281330000.0
# 23:56:30: Waiting for spectra function...
# 23:57:00: Waiting for spectra function...
# 23:57:30: Waiting for spectra function...
# 23:58:01: Waiting for spectra function...
# 23:58:31: Waiting for spectra function...
# 23:59:02: Waiting for spectra function...
# 23:59:32: Found spectra function
# 23:59:33: Waiting for percolator.decoy functions...
# 00:00:03: Waiting for percolator.decoy functions...
# 00:00:34: Found percolator.decoy functions
# 00:00:34: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531281509865
# Billed Duration 120300 milliseconds
# Max Memory Used 1024
# Cost 0.002005401
#
# analyze_spectra
# Min Timestamp 1531281431007
# Max Timestamp 1531281536031
# Max Billed Duration 43000 milliseconds
# Total Billed Duration 334300 milliseconds
# Cost 0.005572781000000001
#
# Combine Spectra
# Timestamp 1531281536346
# Billed Duration 7000 milliseconds
# Max Memory Used 146
# Cost 2.919e-05
#
# Percolator Spectra
# Timestamp 1531281607735
# Billed Duration 64600 milliseconds
# Max Memory Used 887
# Cost 0.003163462
#
# END RESULTS
# Total Cost 0.010770834000000002
# Total Runtime 297.1526602745056 seconds
# Total Billed Duration 526.2 seconds
# Total Memory Used 13321 MB
# bucket maccoss-human-split-spectra expected 51321 actual 0
# bucket maccoss-human-sort-spectra expected 51321 actual 0
# key spectra-1531281327.207525-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3032
# key percolator.target.psms.txt expected 6989 actual 6924
# Deleted 1 input objects
# Deleted 0 split objects
# Deleted 0 sort objects
# Deleted 11 merge objects
# Deleted 11 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# END RESULTS (10 ITERATIONS)
# AVERAGE LOAD RESULTS
# Total Cost 0.0
# Total Runtime 46.195870232582095 seconds
# Total Billed Duration 0.0 seconds
# Total Memory Used 0.0 MB
#
# AVERAGE SPLIT RESULTS
# Total Cost 0.0019272187000000003
# Total Runtime 115.61 seconds
# Total Billed Duration 115.61 seconds
# Total Memory Used 1019.1 MB
#
# AVERAGE ANALYZE RESULTS
# Total Cost 0.006111222
# Total Runtime 67.46 seconds
# Total Billed Duration 366.6 seconds
# Total Memory Used 11234.6 MB
#
# AVERAGE COMBINE RESULTS
# Total Cost 3.06078e-05
# Total Runtime 7.34 seconds
# Total Billed Duration 7.34 seconds
# Total Memory Used 146.0 MB
#
# AVERAGE PERCOLATOR RESULTS
# Total Cost 0.0031424049000000004
# Total Runtime 64.17 seconds
# Total Billed Duration 64.17 seconds
# Total Memory Used 882.3 MB
#
# AVERAGE TOTAL RESULTS
# Total Cost 0.0112114534
# Total Runtime 300.77587023258207 seconds
# Total Billed Duration 553.72 seconds
# Total Memory Used 13282.0 MB

# %%
import benchmark
import json
import importlib
importlib.reload(benchmark)

print("Test merge benchmark on Lambda for large file")

params = json.loads("""{
  "input_name": "TN_CSF_062617_03.ms2",
  "iterations": 10,
  "lambda": true,
  "merge": true,
  "region": "us-west-2",
  "sort": false,
  "timeout": 300,
  "ec2": {
    "ami": "ami-6cbaed14",
    "cost": 0.0464,
    "default_ami": "ami-0ad99772",
    "key": "maccoss",
    "security": "sg-4ea90530",
    "subnet": "subnet-03990a59",
    "timeout": 20,
    "type": "t2.medium",
    "use_ami": true
  },
  "split_spectra": {
    "batch_size": 2000,
    "chunk_size": 50000000,
    "memory_size": 3008,
    "name": "SplitSpectra",
    "output_bucket": "maccoss-human-split-spectra",
    "timeout": 300
  },
  "sort_spectra": {
    "memory_size": 2048,
    "name": "SortSpectra",
    "output_bucket": "maccoss-human-sort-spectra",
    "timeout": 300
  },
  "merge_spectra": {
    "batch_size": 2000,
    "chunk_size": 500000,
    "memory_size": 1024,
    "name": "MergeSpectra",
    "output_bucket": "maccoss-human-merge-spectra",
    "timeout": 300
  },
  "analyze_spectra": {
    "memory_size": 1024,
    "name": "AnalyzeSpectra",
    "num_threads": 1,
    "output_bucket": "maccoss-human-analyze-spectra",
    "timeout": 300
  },
  "combine_spectra_results": {
    "memory_size": 256,
    "name": "CombineSpectra",
    "output_bucket": "maccoss-human-combine-spectra",
    "timeout": 300
  },
  "percolator": {
    "max_train": 50000,
    "memory_size": 3008,
    "name": "Percolator",
    "output_bucket": "maccoss-human-output-spectra",
    "timeout": 300
  }
}
""")
benchmark.run(params)
# Out:
# Test merge benchmark on Lambda for large file
# Current Git commit 6f6fc52 benchmark: Add support for merge and unmerge versions
#
#
# Iteration 0
# spectra-1531319452.111333-1-1-1.ms2 last modified 1531319455000.0
# 10:31:32: Waiting for spectra function...
# 10:32:02: Waiting for spectra function...
# 10:32:33: Waiting for spectra function...
# 10:33:03: Waiting for spectra function...
# 10:33:35: Waiting for spectra function...
# 10:34:05: Waiting for spectra function...
# 10:34:36: Waiting for spectra function...
# 10:35:06: Waiting for spectra function...
# 10:35:37: Waiting for spectra function...
# 10:36:07: Waiting for spectra function...
# 10:36:37: Waiting for spectra function...
# 10:37:08: Waiting for spectra function...
# 10:37:38: Waiting for spectra function...
# 10:38:09: Waiting for spectra function...
# 10:38:39: Waiting for spectra function...
# 10:39:10: Waiting for spectra function...
# 10:39:41: Waiting for spectra function...
# 10:40:11: Waiting for spectra function...
# 10:40:42: Waiting for spectra function...
# 10:41:12: Waiting for spectra function...
# 10:41:42: Waiting for spectra function...
# 10:42:13: Waiting for spectra function...
# 10:42:43: Waiting for spectra function...
# 10:43:14: Found spectra function
# 10:43:15: Waiting for percolator.decoy functions...
# 10:43:45: Found percolator.decoy functions
# 10:43:46: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531319579345
# Billed Duration 87300 milliseconds
# Max Memory Used 664
# Cost 0.004275081
#
# sort_spectra
# Min Timestamp 1531319620728
# Max Timestamp 1531319812236
# Max Billed Duration 292800 milliseconds
# Total Billed Duration 5329200 milliseconds
# Cost 0.177675528
#
# merge_spectra
# Min Timestamp 1531319634752
# Max Timestamp 1531320147264
# Max Billed Duration 300000 milliseconds
# Total Billed Duration 770800 milliseconds
# Cost 0.012849236
#
# analyze_spectra
# Min Timestamp 1531319838809
# Max Timestamp 1531320157335
# Max Billed Duration 20300 milliseconds
# Total Billed Duration 432700 milliseconds
# Cost 0.0072131090000000005
#
# Combine Spectra
# Timestamp 1531320160093
# Billed Duration 8600 milliseconds
# Max Memory Used 109
# Cost 3.5861999999999996e-05
#
# Percolator Spectra
# Timestamp 1531320220397
# Billed Duration 51700 milliseconds
# Max Memory Used 865
# Cost 0.002531749
#
# END RESULTS
# Total Cost 0.20458056499999996
# Total Runtime 800.142251443863 seconds
# Total Billed Duration 6680.3 seconds
# Total Memory Used 45431 MB
# key spectra-1531319452.111333-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3004
# key percolator.target.psms.txt expected 6989 actual 7066
# Deleted 1 input objects
# Deleted 26 split objects
# Deleted 26 sort objects
# Deleted 26 merge objects
# Deleted 26 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 1
# spectra-1531320626.941428-1-1-1.ms2 last modified 1531320630000.0
# 10:51:07: Waiting for spectra function...
# 10:51:37: Waiting for spectra function...
# 10:52:08: Waiting for spectra function...
# 10:52:38: Waiting for spectra function...
# 10:53:09: Waiting for spectra function...
# 10:53:39: Waiting for spectra function...
# 10:54:10: Waiting for spectra function...
# 10:54:40: Waiting for spectra function...
# 10:55:11: Waiting for spectra function...
# 10:55:41: Waiting for spectra function...
# 10:56:12: Waiting for spectra function...
# 10:56:42: Waiting for spectra function...
# 10:57:13: Waiting for spectra function...
# 10:57:43: Waiting for spectra function...
# 10:58:14: Waiting for spectra function...
# 10:58:44: Waiting for spectra function...
# 10:59:15: Waiting for spectra function...
# 10:59:45: Waiting for spectra function...
# 11:00:16: Waiting for spectra function...
# 11:00:46: Waiting for spectra function...
# 11:01:17: Waiting for spectra function...
# 11:01:47: Waiting for spectra function...
# 11:02:18: Found spectra function
# 11:02:18: Waiting for percolator.decoy functions...
# 11:02:49: Waiting for percolator.decoy functions...
# 11:03:19: Found percolator.decoy functions
# 11:03:19: Found percolator.target functions
#
# Split Spectra
# Timestamp 1531320752929
# Billed Duration 86200 milliseconds
# Max Memory Used 668
# Cost 0.004221214
#
# sort_spectra
# Min Timestamp 1531320794635
# Max Timestamp 1531320985540
# Max Billed Duration 283400 milliseconds
# Total Billed Duration 5196700 milliseconds
# Cost 0.173257978
#
# merge_spectra
# Min Timestamp 1531320813097
# Max Timestamp 1531321303873
# Max Billed Duration 300000 milliseconds
# Total Billed Duration 449700 milliseconds
# Cost 0.007496499
#
# analyze_spectra
# Min Timestamp 1531321010949
# Max Timestamp 1531321315279
# Max Billed Duration 19500 milliseconds
# Total Billed Duration 416200 milliseconds
# Cost 0.006938054000000001
#
# Combine Spectra
# Timestamp 1531321316413
# Billed Duration 7700 milliseconds
# Max Memory Used 113
# Cost 3.2109e-05
#
# Percolator Spectra
# Timestamp 1531321375826
# Billed Duration 51900 milliseconds
# Max Memory Used 871
# Cost 0.002541543
#
# END RESULTS
# Total Cost 0.194487397
# Total Runtime 788.3746187210083 seconds
# Total Billed Duration 6208.4 seconds
# Total Memory Used 45868 MB
# key spectra-1531320626.941428-1-1-1.txt expected 251401 actual 251402
# key percolator.target.peptides.txt expected 3103 actual 3004
# key percolator.target.psms.txt expected 6989 actual 7066
# Deleted 1 input objects
# Deleted 26 split objects
# Deleted 26 sort objects
# Deleted 26 merge objects
# Deleted 26 analyze objects
# Deleted 1 combine objects
# Deleted 4 output objects
# --------------------------
#
# Iteration 2
# spectra-1531321872.637242-1-1-1.ms2 last modified 1531321875000.0
# 11:11:51: Waiting for spectra function...
# 11:12:21: Waiting for spectra function...
# 11:12:52: Waiting for spectra function...
# 11:13:22: Waiting for spectra function...
# 11:13:53: Waiting for spectra function...
# 11:14:23: Waiting for spectra function...
# 11:14:54: Waiting for spectra function...
# 11:15:24: Waiting for spectra function...
# 11:15:55: Waiting for spectra function...
# 11:16:25: Waiting for spectra function...
# 11:16:56: Waiting for spectra function...
# 11:17:26: Waiting for spectra function...
# 11:17:57: Waiting for spectra function...
# 11:18:27: Waiting for spectra function...
# 11:18:58: Waiting for spectra function...
# 11:19:28: Waiting for spectra function...
# 11:19:59: Waiting for spectra function...
# 11:20:29: Waiting for spectra function...
# 11:21:00: Waiting for spectra function...
# 11:21:30: Waiting for spectra function...
# 11:22:01: Waiting for spectra function...
# 11:22:31: Waiting for spectra function...
# 11:23:02: Waiting for spectra function...
# 11:23:32: Found spectra function
# 11:23:32: Waiting for percolator.decoy functions...
